# %% [markdown]
# # Introduction
# We are going to first extract all words from 15k words set that has been used in SPINE for word2vec and glove. For that we'll upload a file from link and then extract words from it.

# %%
# Downloading Data
def files(FILEID,FILENAME):
  # !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id={FILEID}' -O '{FILENAME}'
# !mkdir data 
# !mkdir output
input_path='data/'
file_name_train=f'{input_path}word2vec_original_15k_300d_train.txt'
files('1GqxXcA7EOkzlfA8oYIXLxMa72bsUe_xY',file_name_train)
# Out:
# --2021-07-17 23:37:26--  https://docs.google.com/uc?export=download&id=1GqxXcA7EOkzlfA8oYIXLxMa72bsUe_xY
# Resolving docs.google.com (docs.google.com)... 142.250.65.78, 2607:f8b0:4004:837::200e
# Connecting to docs.google.com (docs.google.com)|142.250.65.78|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-10-b4-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/u3s2v8jj9p1bs2h2hptjo8lfuunge8u1/1626564975000/14542752466560403264/*/1GqxXcA7EOkzlfA8oYIXLxMa72bsUe_xY?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2021-07-17 23:37:27--  https://doc-10-b4-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/u3s2v8jj9p1bs2h2hptjo8lfuunge8u1/1626564975000/14542752466560403264/*/1GqxXcA7EOkzlfA8oYIXLxMa72bsUe_xY?e=download
# Resolving doc-10-b4-docs.googleusercontent.com (doc-10-b4-docs.googleusercontent.com)... 172.217.164.161, 2607:f8b0:4004:815::2001
# Connecting to doc-10-b4-docs.googleusercontent.com (doc-10-b4-docs.googleusercontent.com)|172.217.164.161|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘data/word2vec_original_15k_300d_train.txt’
#
# data/word2vec_origi     [  <=>               ]  42.54M   115MB/s    in 0.4s
#
# 2021-07-17 23:37:28 (115 MB/s) - ‘data/word2vec_original_15k_300d_train.txt’ saved [44612372]

# %% [markdown]
# To view files

# %%
# downloaded files
# !ls data
# Out:
# word2vec_original_15k_300d_train.txt

# %% [markdown]
# # Installing Fasttext

# %%
# installing fastText another word embedding
# !pip install fasttext
import fasttext.util
import fasttext
# Out:
# Collecting fasttext
#   Downloading https://files.pythonhosted.org/packages/f8/85/e2b368ab6d3528827b147fdb814f8189acc981a4bc2f99ab894650e05c40/fasttext-0.9.2.tar.gz (68kB)
#      |████████████████████████████████| 71kB 10.1MB/s
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext) (2.7.0)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext) (57.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fasttext) (1.19.5)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3095090 sha256=c6132a6e81ea935a61c345a52ea96973fdbe0eb7328527991c3f8dfd66a0b0bc
#   Stored in directory: /root/.cache/pip/wheels/98/ba/7f/b154944a1cf5a8cee91c154b75231136cc3a3321ab0e30f592
# Successfully built fasttext
# Installing collected packages: fasttext
# Successfully installed fasttext-0.9.2

# %%
database_already_available=True
if database_already_available:

  from google.colab import drive
  drive.mount('/content/gdrive')
  # for extraction
  # !gunzip /content/gdrive/MyDrive/cc.en.300.bin.gz 
  ft = fasttext.load_model('/content/gdrive/MyDrive/cc.en.300.bin')
else:
  fasttext.util.download_model('en', if_exists='ignore')  # English
  ft = fasttext.load_model('cc.en.300.bin')
# Out:
# Mounted at /content/gdrive
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %% [markdown]
# For the extraction of words from the file

# %%
# extracting words from a file
import re
words=[]
txt_words_fileName=f'{input_path}words_train.txt'
with open(file_name_train) as f, open(txt_words_fileName, 'w') as f1:
  pattern=r"[a-z]+"
  words=re.findall(pattern, f.read(),flags=re.IGNORECASE)
  print(f"total words with spaces: {len(words)}")
  words=[word for word in words if word !=""]
  words=list(set(words)) # removing any duplicates
  print(f"total words: {len(words)}")
  for w in words:
    f1.write(w+'\n')
# Out:
# total words with spaces: 17142
# total words: 14942

# %% [markdown]
# Some examples of words

# %%
# some examples
print(words[25:34])
# Out:
# ['orchard', 'beams', 'collected', 'confederate', 'ribs', 'banner', 'turtles', 'lu', 'wind']

# %% [markdown]
# # Example of word vectors

# %%
ft.get_word_vector(words[25])
# Out:
# array([ 4.57834564e-02, -1.24678295e-02, -3.32285976e-03,  5.25756292e-02,
#         8.55483264e-02,  4.16851491e-02,  7.22654015e-02, -1.88667290e-02,
#         6.29564449e-02,  5.02005741e-02, -4.01535630e-02, -1.94597170e-02,
#        -1.38980653e-02, -7.03706890e-02,  5.66957854e-02,  1.31214736e-02,
#        -2.02599610e-03,  7.65393078e-02, -2.08202209e-02,  1.01342667e-02,
#        -7.96847045e-02,  3.28711346e-02,  5.57097793e-03, -1.72753818e-02,
#         1.57043412e-02, -8.79934616e-03,  6.85426295e-02,  1.68008897e-02,
#        -1.75402090e-02,  1.16896413e-01,  7.65092764e-03, -1.99613124e-02,
#        -2.82158609e-02,  2.68546157e-02, -3.78344848e-04, -4.10294486e-03,
#        -4.93034646e-02,  7.44972080e-02,  5.76050580e-02,  1.36979222e-02,
#         1.30498910e-03, -5.58046810e-02, -3.17485519e-02,  2.88453847e-02,
#        -9.27568525e-02, -1.05249165e-02,  5.73772751e-02,  1.17170503e-02,
#        -2.05423404e-02,  1.29165491e-02, -3.05964723e-02, -9.24126729e-02,
#        -4.17730026e-03,  9.23722982e-04, -3.27554792e-02,  1.09727904e-02,
#         6.15707450e-02, -6.66341931e-02, -1.85378660e-02,  5.53747490e-02,
#        -8.17518402e-03,  9.20933485e-02,  8.16254765e-02,  1.82211027e-03,
#        -4.90518734e-02, -1.44352671e-02, -7.35667497e-02, -5.44532342e-03,
#        -3.75993028e-02,  2.89343186e-02,  3.56179150e-03, -8.11064988e-02,
#        -8.37447196e-02,  1.00365601e-01,  5.18654510e-02, -3.51134464e-02,
#        -7.71011710e-02,  4.93332967e-02, -9.99194756e-03, -9.73946415e-03,
#         2.51702778e-02,  1.16593642e-02, -4.55767065e-02, -5.80478739e-03,
#        -8.28727484e-02,  5.72958291e-02,  1.03941187e-02, -3.27312201e-03,
#         4.60099392e-02, -9.16394591e-03, -1.64350830e-02, -2.70303115e-02,
#        -4.43079285e-02, -2.45656185e-02,  4.22609225e-03,  2.64495667e-02,
#         5.61658517e-02,  3.70007455e-02, -3.23193073e-02, -1.35614686e-02,
#         8.45864341e-02,  1.79736800e-02, -1.24119543e-01, -4.79027629e-03,
#        -1.11963355e-03,  1.15726195e-01, -6.65160175e-03, -7.05071241e-02,
#        -8.07032883e-02, -1.35543227e-01,  1.24009773e-02, -3.35167116e-03,
#        -8.81290883e-02,  2.42133476e-02, -5.38293831e-02,  9.66571271e-02,
#         3.47236581e-02,  1.03336051e-02, -2.49507688e-02,  3.56648862e-03,
#        -8.15169811e-02,  2.26839092e-02,  6.63706437e-02,  2.06130557e-02,
#        -2.96357051e-02, -5.42285554e-02,  4.00139205e-02, -1.83914346e-03,
#         9.51214414e-03,  2.53645554e-02, -2.51842476e-02, -4.19424474e-02,
#         1.42165944e-02, -7.51625141e-03,  1.84940100e-02, -1.09198717e-02,
#         1.68508478e-02, -3.16952392e-02,  5.85257215e-03,  2.63963602e-02,
#        -3.74783128e-02, -3.85766253e-02, -1.42559959e-02,  2.75010951e-02,
#        -4.00664955e-02,  2.32178196e-02, -1.33400887e-01,  2.53288858e-02,
#        -3.39410268e-03, -9.30085592e-03,  1.42454598e-02, -3.24834213e-02,
#         7.00948983e-02,  9.35991935e-04,  8.46662521e-02,  8.83294195e-02,
#         1.51204616e-02, -1.02760522e-02, -6.82895407e-02,  3.36439759e-02,
#         7.55623262e-03,  2.47719716e-02,  4.35489230e-02, -9.84972157e-03,
#        -8.30786303e-03, -1.30770564e-01,  4.08436581e-02,  2.24138275e-02,
#         6.04867265e-02, -5.08151427e-02, -4.25900482e-02, -3.02722529e-02,
#        -3.09967902e-02, -3.60817276e-03, -5.33384383e-02,  1.00232391e-02,
#        -2.95601226e-02,  2.33305674e-02,  1.00113973e-01,  2.34673545e-02,
#        -9.93353501e-03,  1.44240037e-02,  6.36262528e-04, -6.10689484e-02,
#         3.69442180e-02, -2.02932656e-02,  1.30077861e-02, -3.84062454e-02,
#         3.68127227e-02, -8.77808183e-02,  3.01761366e-02,  4.21850644e-02,
#         1.80862755e-01, -4.63598594e-03, -7.46591240e-02, -8.28136131e-02,
#         4.64896560e-02, -3.31940502e-02,  4.05219868e-02, -6.99417591e-02,
#         1.46613261e-02,  2.59799622e-02, -1.45422630e-02, -1.11543201e-02,
#         2.98861973e-02,  2.94889119e-02,  2.81802323e-02, -9.58382636e-02,
#         4.27982360e-02,  4.56845537e-02, -4.12952295e-03,  2.09954195e-02,
#         1.61123425e-02, -6.99685961e-02, -1.70962114e-04,  1.39308702e-02,
#        -1.82774961e-02, -7.88491443e-02, -1.93362532e-03,  9.89300199e-04,
#        -5.97563982e-02,  5.97828142e-02,  8.75186920e-02,  3.72809358e-02,
#        -9.79703618e-04,  1.12738237e-02,  2.43492760e-02, -7.73411021e-02,
#         4.43561785e-02, -1.61473360e-02, -7.30524957e-02, -2.44418122e-02,
#         1.84179433e-02, -1.57865733e-02,  6.53939769e-02,  5.60007524e-03,
#         1.61327049e-02, -4.88219075e-02, -4.19571102e-02,  6.77715405e-04,
#         4.69026044e-02,  7.37832785e-02, -1.05985999e-02, -4.44640368e-02,
#         4.90613058e-02, -9.48071778e-02,  3.49795483e-02, -7.93022215e-02,
#        -1.01466820e-01, -2.56256945e-02,  4.32640724e-02, -1.94173807e-03,
#         1.86739750e-02, -4.18049209e-02,  1.01756483e-01,  2.22056918e-02,
#        -7.38850906e-02, -1.73172466e-02, -1.61406100e-02,  7.89339691e-02,
#         3.36743891e-02,  1.06801717e-02, -1.28454226e-03,  8.47993791e-02,
#        -3.61423269e-02, -1.63981859e-02,  5.68273179e-02,  7.41664320e-04,
#        -6.70320615e-02,  6.90678656e-02,  5.86782061e-02,  4.74765263e-02,
#        -3.81925628e-02, -9.05903697e-04, -4.65575233e-02, -5.05209863e-02,
#        -2.38589011e-02, -4.08818722e-02, -4.95520001e-03, -2.52469219e-02,
#         1.35284007e-01, -2.36152373e-02, -3.11097279e-02, -3.04855071e-02,
#         1.84452608e-02,  3.07683945e-02,  9.98142213e-02,  4.49493304e-02,
#         8.12634006e-02, -9.59455501e-03, -1.47966770e-02, -2.69409325e-02,
#        -8.49316940e-02,  9.62322205e-02, -4.48639616e-02, -9.15924236e-02,
#        -1.52665554e-02,  7.07430840e-02,  1.04455911e-01,  2.79684588e-02],
#       dtype=float32)

# %% [markdown]
# Saving word vectors into a file

# %%
def writeVectors(filename,words):
  fid=open(filename,'w')
  for w in words:
    vec= ft.get_word_vector(w)
    fid.write("<pad2a> ")
    fid.write(w)
    fid.write(" <pad2a> ")
    for e in vec:
      fid.write(str(e))
      fid.write(" ")
    fid.write("\n")
filename="fastext_embedding.txt"
writeVectors(filename,words)

# %% [markdown]
# Saving the file to your google drive

# %%
# !cp fastext_embedding.txt /content/gdrive/MyDrive/fastext_embedding.txt

# %% [markdown]
# # Introducing weights
# Creating weights for each error class

# %%
weights_reconstruction=1e3;
weights_PSL=50;
weights_ASL=5;

# %% [markdown]
# ## Datahandler class

# %%
import numpy as np
import logging
from sklearn.datasets import make_blobs
#logging.basicConfig(level=logging.INFO)
logging.basicConfig(level=logging.DEBUG)

class DataHandler:
  def  __init__(self):
    pass
    
  def loadData(self,filename):
    logging.info("Loading data from " + filename )
    #limit = 1000 ## for debnugging. TODO: remove this
    lines = open(filename).readlines()#[:limit] 
    self.words = []
    self.data=[]
    print(f"Total Lines in the file:{len(lines)}")
    for line in lines:
      # tokens = line.strip().split()
      tokens = line.strip().split("<pad2a>")
      tokens_sent=tokens[1]
      tokens_val=tokens[2]
      # tokens_sent=tokens_sent.split()
      tokens_val=tokens_val.split()
      try:
        elements=[[float(v)] for v in tokens_val]
      except:
        print('#############################################')
        print(tokens_val)
        print(np.shape(tokens))
        print(tokens)
        break
      self.data.append(elements)
      self.words.append([tokens_sent])
    self.data=np.asarray(self.data)
    self.data=self.data.squeeze(axis=2)
    print(f'shape of vector space: {np.shape(self.data)}')
    print(f'shape of words: {np.shape(self.words)}')

    # print(self.words[0])
    # print(self.data[0])
    logging.info("Loaded data. #shape = " + str(self.data.shape) )
    logging.info(" #words = %d " %(len(self.words)) )
    self.data_size = self.data.shape[0]
    self.inp_dim = self.data.shape[1]
    self.original_data = self.data[:]
    logging.debug("original_data[0][0:5] = " + str(self.original_data[0][0:5]))

  def getWordsList(self):
    return self.words
  
    

  def getDataShape(self):
    return self.data.shape

  def resetDataOrder(self):
    self.data = self.original_data[:]
    logging.debug("original_data[0][0:5] = " + str(self.original_data[0][0:5]))

  def getNumberOfBatches(self, batch_size):
    return int(( self.data_size + batch_size - 1 ) / batch_size)

  def getBatch(self, i, batch_size, noise_level, denoising):
    batch_y = self.data[i*batch_size:min((i+1)*batch_size, self.data_size)]
    batch_x = batch_y
    if denoising:
      batch_x = batch_y + get_noise_features(batch_y.shape[0], self.inp_dim, noise_level)
    return batch_x, batch_y

  def shuffleTrain(self):
    indices = np.arange(self.data_size)
    np.random.shuffle(indices)
    self.data = self.data[indices]


############################################

############################################
#### data handler class finished############

# %% [markdown]
# ## Model

# %%
# Model
import torch
from torch import nn
import logging
logging.basicConfig(level=logging.INFO)


class SPINEModel(torch.nn.Module):

	def __init__(self, params):
		super(SPINEModel, self).__init__()
		
		# params
		self.inp_dim = params['inp_dim']
		self.hdim = params['hdim']
		self.noise_level = params['noise_level']
		self.getReconstructionLoss = nn.MSELoss()
		self.rho_star = 1.0 - params['sparsity']
		
		# autoencoder
		logging.info("Building model ")
		self.linear1 = nn.Linear(self.inp_dim, self.hdim)
		self.linear2 = nn.Linear(self.hdim, self.inp_dim)
		

	def forward(self, batch_x, batch_y):
		
		# forward
		batch_size = batch_x.size(0)
		linear1_out = self.linear1(batch_x)
    # capped relu
		h = linear1_out.clamp(min=0, max=1) 
		out = self.linear2(h)

		# different terms of the loss
		reconstruction_loss = self.getReconstructionLoss(out, batch_y) # reconstruction loss
		psl_loss = self._getPSLLoss(h, batch_size) 		# partial sparsity loss
		asl_loss = self._getASLLoss(h)    	# average sparsity loss
		total_loss = weights_reconstruction*reconstruction_loss + \
    weights_PSL* psl_loss + weights_ASL*asl_loss
		
		return out, h, total_loss, [reconstruction_loss,psl_loss, asl_loss]


	def _getPSLLoss(self,h, batch_size):
		return torch.sum(h*(1-h))/ (batch_size * self.hdim)


	def _getASLLoss(self, h):
		temp = torch.mean(h, dim=0) - self.rho_star
		temp = temp.clamp(min=0)
		return torch.sum(temp * temp) / self.hdim

# %% [markdown]
# ## Some helper functions

# %%
def compute_sparsity(X):
	non_zeros = 1. * np.count_nonzero(X)
	total = X.size
	sparsity = 100. * (1 - (non_zeros)/total)
	return sparsity

def dump_vectors(X, outfile, words):
  print ("shape", X.shape)
  assert len(X) == len(words) #TODO print error statement
  fw = open(outfile, 'w')
  for i in range(len(words)):
    sent=words[i][:]
    sent=str(sent)
    sent=sent.replace("[","")
    sent=sent.replace("'","")
    sent=sent.replace("]","")
    # print(np.shape(sent[0]))
    # print(sent[0])  
    fw.write("<pad2a>"+ sent+"<pad2a>" )
    for j in X[i,:]:
      fw.write(str(j) + " ")
    fw.write("\n")
  fw.close()

def get_noise_features(n_samples, n_features, noise_amount):
	noise_x,  _ =  make_blobs(n_samples=n_samples, n_features=n_features, 
			cluster_std=noise_amount,
			centers=np.array([np.zeros(n_features)]))
	return noise_x

# %%
import torch
from torch import nn
import argparse
from random import shuffle
import numpy as np
import logging
logging.basicConfig(level=logging.INFO)

class Solver:

	def __init__(self, params):

		# Build data handler
		self.data_handler = DataHandler()
		self.data_handler.loadData(params['input'])
		params['inp_dim'] = self.data_handler.getDataShape()[1]
		logging.info("="*41)


		# Build model
		self.model = SPINEModel(params)
		self.dtype = torch.FloatTensor
		use_cuda = torch.cuda.is_available()
		if use_cuda:
			self.model.cuda()
			self.dtype = torch.cuda.FloatTensor
		self.optimizer = torch.optim.SGD(self.model.parameters(), lr=0.1)
		logging.info("="*41)


	def train(self, params):
		num_epochs, batch_size = params['num_epochs'], params['batch_size'],
		optimizer = self.optimizer
		dtype = self.dtype
		for iteration in range(num_epochs):
			self.data_handler.shuffleTrain()
			num_batches = self.data_handler.getNumberOfBatches(batch_size)
			epoch_losses = np.zeros(4) # rl, asl, psl, total
			for batch_idx in range(num_batches):
				optimizer.zero_grad()
				batch_x, batch_y = self.data_handler.getBatch(batch_idx, batch_size, params['noise_level'], params['denoising'] )
				batch_x = torch.from_numpy(batch_x).type(dtype)
				batch_y = torch.from_numpy(batch_y).type(dtype)
				out, h, loss, loss_terms = self.model(batch_x, batch_y)
				reconstruction_loss, psl_loss, asl_loss = loss_terms
				loss.backward()
				optimizer.step()
				epoch_losses[0]+=reconstruction_loss.item()
				epoch_losses[1]+=asl_loss.item()
				epoch_losses[2]+=psl_loss.item()
				epoch_losses[3]+=loss.item()
			print("After epoch %r, Reconstruction Loss = %.4f, ASL = %.4f,"\
						"PSL = %.4f, and total = %.4f"
						%(iteration+1, epoch_losses[0], epoch_losses[1], epoch_losses[2], epoch_losses[3]) )
			logging.info("After epoch %r, Sparsity = %.1f"
						%(iteration+1, compute_sparsity(h.cpu().data.numpy())))
				#break
			#break

	def getSpineEmbeddings(self, batch_size, params):
		ret = []
		self.data_handler.resetDataOrder()
		num_batches = self.data_handler.getNumberOfBatches(batch_size)
		for batch_idx in range(num_batches):
			batch_x, batch_y = self.data_handler.getBatch(batch_idx, batch_size, params['noise_level'], params['denoising'] )
			batch_x = torch.from_numpy(batch_x).type(self.dtype)
			batch_y = torch.from_numpy(batch_y).type(self.dtype)
			_, h, _, _ = self.model(batch_x, batch_y)
			ret.extend(h.cpu().data.numpy())
		return np.array(ret)

	def getWordsList(self):
		return self.data_handler.getWordsList()

# %%
#########################################################
# main program
def main(hdim=1000,
                  denoising=False,
                  noise_level=0.2,
                  num_epochs=100,
                  batch_size=64,
                  sparsity=0.85,
                  fileName='word2vec_original_15k_300d_train.txt'):
  params=dict()
  # params['inp_dim']=2000
  params['hdim']=hdim
  params['noise_level']=noise_level
  params['denoising']=denoising
  params['sparsity']=sparsity
  params['num_epochs']=num_epochs
  params['batch_size']=batch_size
  params['input']=fileName
  params['output']=fileName
  solver = Solver(params)
  solver.train( params )
  # dumping the final vectors
  logging.info("Dumping the final SPine embeddings")
  output_path = params['output'] + "_SPINE.spine"
  final_batch_size = 512
  spine_embeddings = solver.getSpineEmbeddings(final_batch_size, params)
  dump_vectors(spine_embeddings, output_path, solver.getWordsList())

# %% [markdown]
# # Training

# %%
weights_reconstruction=1;
weights_PSL=0.8;
weights_ASL=1;
epochs=800
drive_path='gdrive/MyDrive/'
# filename=drive_path+filename
filename="/content/fastext_embedding.txt"
hdim=1000
denoising=True
noise_level=0.6
batch_size=512
sparsity=0.85
main(num_epochs=epochs,denoising=denoising,noise_level=noise_level,
     hdim=hdim,batch_size=batch_size,sparsity=sparsity,
     fileName=filename)
# Out:
# INFO:root:Loading data from /content/fastext_embedding.txt
# Total Lines in the file:14942
# INFO:root:Loaded data. #shape = (14942, 300)
# INFO:root: #words = 14942
# DEBUG:root:original_data[0][0:5] = [-0.04570577 -0.07722437 -0.0188346   0.05359886  0.140308  ]
# INFO:root:=========================================
# INFO:root:Building model
# INFO:root:=========================================
# shape of vector space: (14942, 300)
# shape of words: (14942, 1)
# INFO:root:After epoch 1, Sparsity = 50.4
# After epoch 1, Reconstruction Loss = 0.7165, ASL = 0.0025,PSL = 2.3519, and total = 2.6005
# INFO:root:After epoch 2, Sparsity = 50.1
# After epoch 2, Reconstruction Loss = 0.6192, ASL = 0.0025,PSL = 2.3470, and total = 2.4993
# INFO:root:After epoch 3, Sparsity = 50.4
# After epoch 3, Reconstruction Loss = 0.5751, ASL = 0.0023,PSL = 2.3400, and total = 2.4493
# INFO:root:After epoch 4, Sparsity = 50.4
# After epoch 4, Reconstruction Loss = 0.5550, ASL = 0.0022,PSL = 2.3374, and total = 2.4271
# INFO:root:After epoch 5, Sparsity = 50.5
# After epoch 5, Reconstruction Loss = 0.5432, ASL = 0.0022,PSL = 2.3298, and total = 2.4092
# INFO:root:After epoch 6, Sparsity = 50.3
# After epoch 6, Reconstruction Loss = 0.5374, ASL = 0.0020,PSL = 2.3254, and total = 2.3997
# INFO:root:After epoch 7, Sparsity = 50.6
# After epoch 7, Reconstruction Loss = 0.5327, ASL = 0.0019,PSL = 2.3193, and total = 2.3900
# INFO:root:After epoch 8, Sparsity = 50.4
# After epoch 8, Reconstruction Loss = 0.5290, ASL = 0.0018,PSL = 2.3154, and total = 2.3831
# INFO:root:After epoch 9, Sparsity = 50.9
# After epoch 9, Reconstruction Loss = 0.5258, ASL = 0.0017,PSL = 2.3096, and total = 2.3752
# INFO:root:After epoch 10, Sparsity = 50.8
# After epoch 10, Reconstruction Loss = 0.5215, ASL = 0.0016,PSL = 2.3035, and total = 2.3659
# INFO:root:After epoch 11, Sparsity = 51.0
# After epoch 11, Reconstruction Loss = 0.5173, ASL = 0.0016,PSL = 2.3000, and total = 2.3589
# INFO:root:After epoch 12, Sparsity = 51.1
# After epoch 12, Reconstruction Loss = 0.5150, ASL = 0.0015,PSL = 2.2934, and total = 2.3512
# INFO:root:After epoch 13, Sparsity = 51.2
# After epoch 13, Reconstruction Loss = 0.5130, ASL = 0.0015,PSL = 2.2896, and total = 2.3461
# INFO:root:After epoch 14, Sparsity = 51.1
# After epoch 14, Reconstruction Loss = 0.5092, ASL = 0.0013,PSL = 2.2835, and total = 2.3373
# INFO:root:After epoch 15, Sparsity = 51.5
# After epoch 15, Reconstruction Loss = 0.5062, ASL = 0.0013,PSL = 2.2775, and total = 2.3294
# INFO:root:After epoch 16, Sparsity = 51.2
# After epoch 16, Reconstruction Loss = 0.5034, ASL = 0.0012,PSL = 2.2743, and total = 2.3241
# INFO:root:After epoch 17, Sparsity = 51.4
# After epoch 17, Reconstruction Loss = 0.4992, ASL = 0.0011,PSL = 2.2679, and total = 2.3146
# INFO:root:After epoch 18, Sparsity = 51.6
# After epoch 18, Reconstruction Loss = 0.4971, ASL = 0.0011,PSL = 2.2631, and total = 2.3087
# INFO:root:After epoch 19, Sparsity = 51.8
# After epoch 19, Reconstruction Loss = 0.4938, ASL = 0.0010,PSL = 2.2586, and total = 2.3017
# INFO:root:After epoch 20, Sparsity = 51.5
# After epoch 20, Reconstruction Loss = 0.4914, ASL = 0.0010,PSL = 2.2527, and total = 2.2946
# INFO:root:After epoch 21, Sparsity = 51.9
# After epoch 21, Reconstruction Loss = 0.4888, ASL = 0.0009,PSL = 2.2469, and total = 2.2872
# INFO:root:After epoch 22, Sparsity = 52.1
# After epoch 22, Reconstruction Loss = 0.4860, ASL = 0.0008,PSL = 2.2409, and total = 2.2795
# INFO:root:After epoch 23, Sparsity = 52.0
# After epoch 23, Reconstruction Loss = 0.4843, ASL = 0.0008,PSL = 2.2382, and total = 2.2756
# INFO:root:After epoch 24, Sparsity = 52.0
# After epoch 24, Reconstruction Loss = 0.4804, ASL = 0.0008,PSL = 2.2329, and total = 2.2675
# INFO:root:After epoch 25, Sparsity = 52.2
# After epoch 25, Reconstruction Loss = 0.4790, ASL = 0.0007,PSL = 2.2267, and total = 2.2611
# INFO:root:After epoch 26, Sparsity = 52.3
# After epoch 26, Reconstruction Loss = 0.4767, ASL = 0.0007,PSL = 2.2208, and total = 2.2540
# INFO:root:After epoch 27, Sparsity = 52.3
# After epoch 27, Reconstruction Loss = 0.4731, ASL = 0.0007,PSL = 2.2170, and total = 2.2473
# INFO:root:After epoch 28, Sparsity = 52.3
# After epoch 28, Reconstruction Loss = 0.4694, ASL = 0.0006,PSL = 2.2128, and total = 2.2402
# INFO:root:After epoch 29, Sparsity = 52.6
# After epoch 29, Reconstruction Loss = 0.4667, ASL = 0.0006,PSL = 2.2081, and total = 2.2337
# INFO:root:After epoch 30, Sparsity = 52.4
# After epoch 30, Reconstruction Loss = 0.4636, ASL = 0.0005,PSL = 2.2011, and total = 2.2250
# INFO:root:After epoch 31, Sparsity = 52.8
# After epoch 31, Reconstruction Loss = 0.4622, ASL = 0.0005,PSL = 2.1983, and total = 2.2214
# INFO:root:After epoch 32, Sparsity = 52.8
# After epoch 32, Reconstruction Loss = 0.4604, ASL = 0.0005,PSL = 2.1917, and total = 2.2142
# INFO:root:After epoch 33, Sparsity = 52.7
# After epoch 33, Reconstruction Loss = 0.4564, ASL = 0.0005,PSL = 2.1859, and total = 2.2056
# INFO:root:After epoch 34, Sparsity = 53.0
# After epoch 34, Reconstruction Loss = 0.4572, ASL = 0.0004,PSL = 2.1831, and total = 2.2041
# INFO:root:After epoch 35, Sparsity = 53.1
# After epoch 35, Reconstruction Loss = 0.4535, ASL = 0.0004,PSL = 2.1772, and total = 2.1957
# INFO:root:After epoch 36, Sparsity = 53.1
# After epoch 36, Reconstruction Loss = 0.4514, ASL = 0.0004,PSL = 2.1726, and total = 2.1899
# INFO:root:After epoch 37, Sparsity = 53.3
# After epoch 37, Reconstruction Loss = 0.4510, ASL = 0.0004,PSL = 2.1672, and total = 2.1851
# INFO:root:After epoch 38, Sparsity = 53.3
# After epoch 38, Reconstruction Loss = 0.4455, ASL = 0.0003,PSL = 2.1622, and total = 2.1756
# INFO:root:After epoch 39, Sparsity = 53.1
# After epoch 39, Reconstruction Loss = 0.4413, ASL = 0.0003,PSL = 2.1567, and total = 2.1670
# INFO:root:After epoch 40, Sparsity = 53.3
# After epoch 40, Reconstruction Loss = 0.4403, ASL = 0.0003,PSL = 2.1535, and total = 2.1634
# INFO:root:After epoch 41, Sparsity = 53.5
# After epoch 41, Reconstruction Loss = 0.4394, ASL = 0.0003,PSL = 2.1476, and total = 2.1577
# INFO:root:After epoch 42, Sparsity = 53.8
# After epoch 42, Reconstruction Loss = 0.4370, ASL = 0.0002,PSL = 2.1411, and total = 2.1501
# INFO:root:After epoch 43, Sparsity = 53.6
# After epoch 43, Reconstruction Loss = 0.4345, ASL = 0.0002,PSL = 2.1373, and total = 2.1446
# INFO:root:After epoch 44, Sparsity = 53.7
# After epoch 44, Reconstruction Loss = 0.4333, ASL = 0.0002,PSL = 2.1319, and total = 2.1391
# INFO:root:After epoch 45, Sparsity = 54.0
# After epoch 45, Reconstruction Loss = 0.4304, ASL = 0.0002,PSL = 2.1297, and total = 2.1344
# INFO:root:After epoch 46, Sparsity = 53.9
# After epoch 46, Reconstruction Loss = 0.4283, ASL = 0.0002,PSL = 2.1233, and total = 2.1271
# INFO:root:After epoch 47, Sparsity = 54.0
# After epoch 47, Reconstruction Loss = 0.4260, ASL = 0.0002,PSL = 2.1170, and total = 2.1197
# INFO:root:After epoch 48, Sparsity = 53.8
# After epoch 48, Reconstruction Loss = 0.4239, ASL = 0.0002,PSL = 2.1123, and total = 2.1140
# INFO:root:After epoch 49, Sparsity = 54.4
# After epoch 49, Reconstruction Loss = 0.4219, ASL = 0.0002,PSL = 2.1088, and total = 2.1091
# INFO:root:After epoch 50, Sparsity = 54.3
# After epoch 50, Reconstruction Loss = 0.4208, ASL = 0.0001,PSL = 2.1034, and total = 2.1037
# INFO:root:After epoch 51, Sparsity = 53.8
# After epoch 51, Reconstruction Loss = 0.4171, ASL = 0.0002,PSL = 2.0983, and total = 2.0959
# INFO:root:After epoch 52, Sparsity = 54.5
# After epoch 52, Reconstruction Loss = 0.4157, ASL = 0.0001,PSL = 2.0926, and total = 2.0899
# INFO:root:After epoch 53, Sparsity = 54.8
# After epoch 53, Reconstruction Loss = 0.4151, ASL = 0.0001,PSL = 2.0887, and total = 2.0862
# INFO:root:After epoch 54, Sparsity = 54.7
# After epoch 54, Reconstruction Loss = 0.4123, ASL = 0.0001,PSL = 2.0840, and total = 2.0797
# INFO:root:After epoch 55, Sparsity = 54.4
# After epoch 55, Reconstruction Loss = 0.4104, ASL = 0.0001,PSL = 2.0783, and total = 2.0731
# INFO:root:After epoch 56, Sparsity = 55.2
# After epoch 56, Reconstruction Loss = 0.4093, ASL = 0.0001,PSL = 2.0733, and total = 2.0680
# INFO:root:After epoch 57, Sparsity = 54.9
# After epoch 57, Reconstruction Loss = 0.4076, ASL = 0.0001,PSL = 2.0691, and total = 2.0630
# INFO:root:After epoch 58, Sparsity = 54.7
# After epoch 58, Reconstruction Loss = 0.4041, ASL = 0.0001,PSL = 2.0635, and total = 2.0550
# INFO:root:After epoch 59, Sparsity = 55.0
# After epoch 59, Reconstruction Loss = 0.4033, ASL = 0.0001,PSL = 2.0606, and total = 2.0519
# INFO:root:After epoch 60, Sparsity = 55.2
# After epoch 60, Reconstruction Loss = 0.4014, ASL = 0.0001,PSL = 2.0537, and total = 2.0444
# INFO:root:After epoch 61, Sparsity = 55.6
# After epoch 61, Reconstruction Loss = 0.4012, ASL = 0.0001,PSL = 2.0496, and total = 2.0409
# INFO:root:After epoch 62, Sparsity = 54.9
# After epoch 62, Reconstruction Loss = 0.3971, ASL = 0.0001,PSL = 2.0467, and total = 2.0346
# INFO:root:After epoch 63, Sparsity = 55.0
# After epoch 63, Reconstruction Loss = 0.3963, ASL = 0.0001,PSL = 2.0393, and total = 2.0278
# INFO:root:After epoch 64, Sparsity = 55.5
# After epoch 64, Reconstruction Loss = 0.3937, ASL = 0.0001,PSL = 2.0352, and total = 2.0220
# INFO:root:After epoch 65, Sparsity = 55.0
# After epoch 65, Reconstruction Loss = 0.3915, ASL = 0.0000,PSL = 2.0301, and total = 2.0156
# INFO:root:After epoch 66, Sparsity = 55.4
# After epoch 66, Reconstruction Loss = 0.3899, ASL = 0.0001,PSL = 2.0275, and total = 2.0119
# INFO:root:After epoch 67, Sparsity = 55.8
# After epoch 67, Reconstruction Loss = 0.3871, ASL = 0.0001,PSL = 2.0201, and total = 2.0032
# INFO:root:After epoch 68, Sparsity = 55.7
# After epoch 68, Reconstruction Loss = 0.3897, ASL = 0.0000,PSL = 2.0170, and total = 2.0034
# INFO:root:After epoch 69, Sparsity = 55.7
# After epoch 69, Reconstruction Loss = 0.3847, ASL = 0.0000,PSL = 2.0107, and total = 1.9933
# INFO:root:After epoch 70, Sparsity = 55.9
# After epoch 70, Reconstruction Loss = 0.3839, ASL = 0.0000,PSL = 2.0053, and total = 1.9882
# INFO:root:After epoch 71, Sparsity = 56.2
# After epoch 71, Reconstruction Loss = 0.3832, ASL = 0.0000,PSL = 2.0024, and total = 1.9851
# INFO:root:After epoch 72, Sparsity = 56.0
# After epoch 72, Reconstruction Loss = 0.3804, ASL = 0.0000,PSL = 1.9975, and total = 1.9785
# INFO:root:After epoch 73, Sparsity = 56.3
# After epoch 73, Reconstruction Loss = 0.3805, ASL = 0.0000,PSL = 1.9923, and total = 1.9744
# INFO:root:After epoch 74, Sparsity = 55.7
# After epoch 74, Reconstruction Loss = 0.3764, ASL = 0.0000,PSL = 1.9887, and total = 1.9674
# INFO:root:After epoch 75, Sparsity = 56.5
# After epoch 75, Reconstruction Loss = 0.3765, ASL = 0.0000,PSL = 1.9826, and total = 1.9626
# INFO:root:After epoch 76, Sparsity = 56.3
# After epoch 76, Reconstruction Loss = 0.3744, ASL = 0.0000,PSL = 1.9797, and total = 1.9582
# INFO:root:After epoch 77, Sparsity = 56.3
# After epoch 77, Reconstruction Loss = 0.3747, ASL = 0.0000,PSL = 1.9747, and total = 1.9544
# INFO:root:After epoch 78, Sparsity = 56.0
# After epoch 78, Reconstruction Loss = 0.3727, ASL = 0.0000,PSL = 1.9704, and total = 1.9491
# INFO:root:After epoch 79, Sparsity = 56.4
# After epoch 79, Reconstruction Loss = 0.3710, ASL = 0.0000,PSL = 1.9647, and total = 1.9428
# INFO:root:After epoch 80, Sparsity = 56.4
# After epoch 80, Reconstruction Loss = 0.3678, ASL = 0.0000,PSL = 1.9592, and total = 1.9352
# INFO:root:After epoch 81, Sparsity = 57.1
# After epoch 81, Reconstruction Loss = 0.3659, ASL = 0.0000,PSL = 1.9541, and total = 1.9292
# INFO:root:After epoch 82, Sparsity = 56.8
# After epoch 82, Reconstruction Loss = 0.3653, ASL = 0.0000,PSL = 1.9511, and total = 1.9262
# INFO:root:After epoch 83, Sparsity = 57.0
# After epoch 83, Reconstruction Loss = 0.3633, ASL = 0.0000,PSL = 1.9458, and total = 1.9200
# INFO:root:After epoch 84, Sparsity = 56.9
# After epoch 84, Reconstruction Loss = 0.3633, ASL = 0.0000,PSL = 1.9401, and total = 1.9154
# INFO:root:After epoch 85, Sparsity = 57.2
# After epoch 85, Reconstruction Loss = 0.3606, ASL = 0.0000,PSL = 1.9338, and total = 1.9076
# INFO:root:After epoch 86, Sparsity = 56.7
# After epoch 86, Reconstruction Loss = 0.3602, ASL = 0.0000,PSL = 1.9314, and total = 1.9054
# INFO:root:After epoch 87, Sparsity = 57.2
# After epoch 87, Reconstruction Loss = 0.3581, ASL = 0.0000,PSL = 1.9282, and total = 1.9007
# INFO:root:After epoch 88, Sparsity = 57.1
# After epoch 88, Reconstruction Loss = 0.3571, ASL = 0.0000,PSL = 1.9204, and total = 1.8934
# INFO:root:After epoch 89, Sparsity = 57.5
# After epoch 89, Reconstruction Loss = 0.3561, ASL = 0.0000,PSL = 1.9166, and total = 1.8894
# INFO:root:After epoch 90, Sparsity = 57.3
# After epoch 90, Reconstruction Loss = 0.3543, ASL = 0.0000,PSL = 1.9113, and total = 1.8833
# INFO:root:After epoch 91, Sparsity = 57.2
# After epoch 91, Reconstruction Loss = 0.3527, ASL = 0.0000,PSL = 1.9074, and total = 1.8786
# INFO:root:After epoch 92, Sparsity = 57.6
# After epoch 92, Reconstruction Loss = 0.3514, ASL = 0.0000,PSL = 1.9044, and total = 1.8749
# INFO:root:After epoch 93, Sparsity = 57.8
# After epoch 93, Reconstruction Loss = 0.3511, ASL = 0.0000,PSL = 1.9006, and total = 1.8715
# INFO:root:After epoch 94, Sparsity = 57.6
# After epoch 94, Reconstruction Loss = 0.3500, ASL = 0.0000,PSL = 1.8934, and total = 1.8647
# INFO:root:After epoch 95, Sparsity = 57.9
# After epoch 95, Reconstruction Loss = 0.3489, ASL = 0.0000,PSL = 1.8899, and total = 1.8608
# INFO:root:After epoch 96, Sparsity = 57.8
# After epoch 96, Reconstruction Loss = 0.3466, ASL = 0.0000,PSL = 1.8852, and total = 1.8548
# INFO:root:After epoch 97, Sparsity = 57.6
# After epoch 97, Reconstruction Loss = 0.3464, ASL = 0.0000,PSL = 1.8812, and total = 1.8513
# INFO:root:After epoch 98, Sparsity = 58.2
# After epoch 98, Reconstruction Loss = 0.3450, ASL = 0.0000,PSL = 1.8748, and total = 1.8448
# INFO:root:After epoch 99, Sparsity = 58.6
# After epoch 99, Reconstruction Loss = 0.3453, ASL = 0.0000,PSL = 1.8714, and total = 1.8425
# INFO:root:After epoch 100, Sparsity = 57.9
# After epoch 100, Reconstruction Loss = 0.3421, ASL = 0.0000,PSL = 1.8678, and total = 1.8363
# INFO:root:After epoch 101, Sparsity = 58.0
# After epoch 101, Reconstruction Loss = 0.3408, ASL = 0.0000,PSL = 1.8615, and total = 1.8300
# INFO:root:After epoch 102, Sparsity = 58.6
# After epoch 102, Reconstruction Loss = 0.3404, ASL = 0.0000,PSL = 1.8570, and total = 1.8260
# INFO:root:After epoch 103, Sparsity = 58.5
# After epoch 103, Reconstruction Loss = 0.3380, ASL = 0.0000,PSL = 1.8518, and total = 1.8194
# INFO:root:After epoch 104, Sparsity = 58.4
# After epoch 104, Reconstruction Loss = 0.3376, ASL = 0.0000,PSL = 1.8482, and total = 1.8162
# INFO:root:After epoch 105, Sparsity = 58.3
# After epoch 105, Reconstruction Loss = 0.3352, ASL = 0.0000,PSL = 1.8446, and total = 1.8109
# INFO:root:After epoch 106, Sparsity = 58.3
# After epoch 106, Reconstruction Loss = 0.3349, ASL = 0.0000,PSL = 1.8397, and total = 1.8066
# INFO:root:After epoch 107, Sparsity = 58.6
# After epoch 107, Reconstruction Loss = 0.3330, ASL = 0.0000,PSL = 1.8367, and total = 1.8024
# INFO:root:After epoch 108, Sparsity = 58.9
# After epoch 108, Reconstruction Loss = 0.3337, ASL = 0.0000,PSL = 1.8287, and total = 1.7967
# INFO:root:After epoch 109, Sparsity = 58.8
# After epoch 109, Reconstruction Loss = 0.3319, ASL = 0.0000,PSL = 1.8262, and total = 1.7928
# INFO:root:After epoch 110, Sparsity = 59.0
# After epoch 110, Reconstruction Loss = 0.3300, ASL = 0.0000,PSL = 1.8201, and total = 1.7861
# INFO:root:After epoch 111, Sparsity = 59.2
# After epoch 111, Reconstruction Loss = 0.3302, ASL = 0.0000,PSL = 1.8159, and total = 1.7830
# INFO:root:After epoch 112, Sparsity = 59.4
# After epoch 112, Reconstruction Loss = 0.3284, ASL = 0.0000,PSL = 1.8133, and total = 1.7790
# INFO:root:After epoch 113, Sparsity = 58.8
# After epoch 113, Reconstruction Loss = 0.3263, ASL = 0.0000,PSL = 1.8076, and total = 1.7724
# INFO:root:After epoch 114, Sparsity = 59.1
# After epoch 114, Reconstruction Loss = 0.3266, ASL = 0.0000,PSL = 1.8035, and total = 1.7694
# INFO:root:After epoch 115, Sparsity = 59.3
# After epoch 115, Reconstruction Loss = 0.3250, ASL = 0.0000,PSL = 1.7986, and total = 1.7639
# INFO:root:After epoch 116, Sparsity = 59.4
# After epoch 116, Reconstruction Loss = 0.3244, ASL = 0.0000,PSL = 1.7940, and total = 1.7596
# INFO:root:After epoch 117, Sparsity = 59.5
# After epoch 117, Reconstruction Loss = 0.3239, ASL = 0.0000,PSL = 1.7897, and total = 1.7556
# INFO:root:After epoch 118, Sparsity = 59.7
# After epoch 118, Reconstruction Loss = 0.3208, ASL = 0.0000,PSL = 1.7847, and total = 1.7485
# INFO:root:After epoch 119, Sparsity = 59.7
# After epoch 119, Reconstruction Loss = 0.3210, ASL = 0.0000,PSL = 1.7815, and total = 1.7462
# INFO:root:After epoch 120, Sparsity = 60.0
# After epoch 120, Reconstruction Loss = 0.3191, ASL = 0.0000,PSL = 1.7773, and total = 1.7409
# INFO:root:After epoch 121, Sparsity = 60.1
# After epoch 121, Reconstruction Loss = 0.3185, ASL = 0.0000,PSL = 1.7704, and total = 1.7348
# INFO:root:After epoch 122, Sparsity = 60.0
# After epoch 122, Reconstruction Loss = 0.3175, ASL = 0.0000,PSL = 1.7650, and total = 1.7296
# INFO:root:After epoch 123, Sparsity = 59.6
# After epoch 123, Reconstruction Loss = 0.3165, ASL = 0.0000,PSL = 1.7626, and total = 1.7266
# INFO:root:After epoch 124, Sparsity = 60.2
# After epoch 124, Reconstruction Loss = 0.3147, ASL = 0.0000,PSL = 1.7575, and total = 1.7207
# INFO:root:After epoch 125, Sparsity = 59.7
# After epoch 125, Reconstruction Loss = 0.3146, ASL = 0.0000,PSL = 1.7540, and total = 1.7178
# INFO:root:After epoch 126, Sparsity = 60.3
# After epoch 126, Reconstruction Loss = 0.3138, ASL = 0.0000,PSL = 1.7487, and total = 1.7128
# INFO:root:After epoch 127, Sparsity = 60.0
# After epoch 127, Reconstruction Loss = 0.3118, ASL = 0.0000,PSL = 1.7449, and total = 1.7077
# INFO:root:After epoch 128, Sparsity = 60.2
# After epoch 128, Reconstruction Loss = 0.3114, ASL = 0.0000,PSL = 1.7390, and total = 1.7026
# INFO:root:After epoch 129, Sparsity = 60.2
# After epoch 129, Reconstruction Loss = 0.3104, ASL = 0.0000,PSL = 1.7340, and total = 1.6976
# INFO:root:After epoch 130, Sparsity = 60.6
# After epoch 130, Reconstruction Loss = 0.3099, ASL = 0.0000,PSL = 1.7317, and total = 1.6953
# INFO:root:After epoch 131, Sparsity = 60.4
# After epoch 131, Reconstruction Loss = 0.3104, ASL = 0.0000,PSL = 1.7284, and total = 1.6932
# INFO:root:After epoch 132, Sparsity = 60.8
# After epoch 132, Reconstruction Loss = 0.3103, ASL = 0.0000,PSL = 1.7226, and total = 1.6883
# INFO:root:After epoch 133, Sparsity = 60.3
# After epoch 133, Reconstruction Loss = 0.3061, ASL = 0.0000,PSL = 1.7183, and total = 1.6808
# INFO:root:After epoch 134, Sparsity = 61.0
# After epoch 134, Reconstruction Loss = 0.3049, ASL = 0.0000,PSL = 1.7146, and total = 1.6765
# INFO:root:After epoch 135, Sparsity = 60.8
# After epoch 135, Reconstruction Loss = 0.3046, ASL = 0.0000,PSL = 1.7096, and total = 1.6723
# INFO:root:After epoch 136, Sparsity = 61.2
# After epoch 136, Reconstruction Loss = 0.3045, ASL = 0.0000,PSL = 1.7056, and total = 1.6689
# INFO:root:After epoch 137, Sparsity = 61.3
# After epoch 137, Reconstruction Loss = 0.3038, ASL = 0.0000,PSL = 1.7017, and total = 1.6652
# INFO:root:After epoch 138, Sparsity = 61.2
# After epoch 138, Reconstruction Loss = 0.3037, ASL = 0.0000,PSL = 1.6969, and total = 1.6612
# INFO:root:After epoch 139, Sparsity = 61.5
# After epoch 139, Reconstruction Loss = 0.3030, ASL = 0.0000,PSL = 1.6908, and total = 1.6557
# INFO:root:After epoch 140, Sparsity = 61.2
# After epoch 140, Reconstruction Loss = 0.3014, ASL = 0.0000,PSL = 1.6896, and total = 1.6531
# INFO:root:After epoch 141, Sparsity = 61.5
# After epoch 141, Reconstruction Loss = 0.3004, ASL = 0.0000,PSL = 1.6820, and total = 1.6460
# INFO:root:After epoch 142, Sparsity = 61.3
# After epoch 142, Reconstruction Loss = 0.2981, ASL = 0.0000,PSL = 1.6783, and total = 1.6407
# INFO:root:After epoch 143, Sparsity = 61.3
# After epoch 143, Reconstruction Loss = 0.2973, ASL = 0.0000,PSL = 1.6760, and total = 1.6381
# INFO:root:After epoch 144, Sparsity = 61.8
# After epoch 144, Reconstruction Loss = 0.2989, ASL = 0.0000,PSL = 1.6693, and total = 1.6343
# INFO:root:After epoch 145, Sparsity = 61.6
# After epoch 145, Reconstruction Loss = 0.2962, ASL = 0.0000,PSL = 1.6659, and total = 1.6289
# INFO:root:After epoch 146, Sparsity = 61.5
# After epoch 146, Reconstruction Loss = 0.2951, ASL = 0.0000,PSL = 1.6623, and total = 1.6250
# INFO:root:After epoch 147, Sparsity = 61.7
# After epoch 147, Reconstruction Loss = 0.2946, ASL = 0.0000,PSL = 1.6567, and total = 1.6200
# INFO:root:After epoch 148, Sparsity = 62.3
# After epoch 148, Reconstruction Loss = 0.2943, ASL = 0.0000,PSL = 1.6535, and total = 1.6171
# INFO:root:After epoch 149, Sparsity = 61.9
# After epoch 149, Reconstruction Loss = 0.2933, ASL = 0.0000,PSL = 1.6493, and total = 1.6127
# INFO:root:After epoch 150, Sparsity = 62.6
# After epoch 150, Reconstruction Loss = 0.2936, ASL = 0.0000,PSL = 1.6417, and total = 1.6069
# INFO:root:After epoch 151, Sparsity = 62.0
# After epoch 151, Reconstruction Loss = 0.2927, ASL = 0.0000,PSL = 1.6385, and total = 1.6036
# INFO:root:After epoch 152, Sparsity = 62.4
# After epoch 152, Reconstruction Loss = 0.2904, ASL = 0.0000,PSL = 1.6336, and total = 1.5973
# INFO:root:After epoch 153, Sparsity = 62.3
# After epoch 153, Reconstruction Loss = 0.2907, ASL = 0.0000,PSL = 1.6308, and total = 1.5954
# INFO:root:After epoch 154, Sparsity = 62.3
# After epoch 154, Reconstruction Loss = 0.2896, ASL = 0.0000,PSL = 1.6267, and total = 1.5910
# INFO:root:After epoch 155, Sparsity = 62.3
# After epoch 155, Reconstruction Loss = 0.2906, ASL = 0.0000,PSL = 1.6220, and total = 1.5882
# INFO:root:After epoch 156, Sparsity = 62.6
# After epoch 156, Reconstruction Loss = 0.2884, ASL = 0.0000,PSL = 1.6195, and total = 1.5840
# INFO:root:After epoch 157, Sparsity = 62.6
# After epoch 157, Reconstruction Loss = 0.2875, ASL = 0.0000,PSL = 1.6141, and total = 1.5788
# INFO:root:After epoch 158, Sparsity = 62.1
# After epoch 158, Reconstruction Loss = 0.2857, ASL = 0.0000,PSL = 1.6095, and total = 1.5733
# INFO:root:After epoch 159, Sparsity = 62.3
# After epoch 159, Reconstruction Loss = 0.2855, ASL = 0.0000,PSL = 1.6070, and total = 1.5711
# INFO:root:After epoch 160, Sparsity = 62.4
# After epoch 160, Reconstruction Loss = 0.2847, ASL = 0.0000,PSL = 1.6028, and total = 1.5669
# INFO:root:After epoch 161, Sparsity = 62.9
# After epoch 161, Reconstruction Loss = 0.2850, ASL = 0.0000,PSL = 1.5981, and total = 1.5635
# INFO:root:After epoch 162, Sparsity = 62.7
# After epoch 162, Reconstruction Loss = 0.2832, ASL = 0.0000,PSL = 1.5918, and total = 1.5567
# INFO:root:After epoch 163, Sparsity = 62.9
# After epoch 163, Reconstruction Loss = 0.2823, ASL = 0.0000,PSL = 1.5879, and total = 1.5527
# INFO:root:After epoch 164, Sparsity = 62.8
# After epoch 164, Reconstruction Loss = 0.2817, ASL = 0.0000,PSL = 1.5832, and total = 1.5483
# INFO:root:After epoch 165, Sparsity = 63.3
# After epoch 165, Reconstruction Loss = 0.2810, ASL = 0.0000,PSL = 1.5793, and total = 1.5444
# INFO:root:After epoch 166, Sparsity = 62.7
# After epoch 166, Reconstruction Loss = 0.2820, ASL = 0.0000,PSL = 1.5775, and total = 1.5440
# INFO:root:After epoch 167, Sparsity = 63.0
# After epoch 167, Reconstruction Loss = 0.2788, ASL = 0.0000,PSL = 1.5708, and total = 1.5355
# INFO:root:After epoch 168, Sparsity = 63.4
# After epoch 168, Reconstruction Loss = 0.2782, ASL = 0.0000,PSL = 1.5652, and total = 1.5304
# INFO:root:After epoch 169, Sparsity = 63.3
# After epoch 169, Reconstruction Loss = 0.2777, ASL = 0.0000,PSL = 1.5633, and total = 1.5283
# INFO:root:After epoch 170, Sparsity = 63.2
# After epoch 170, Reconstruction Loss = 0.2773, ASL = 0.0000,PSL = 1.5579, and total = 1.5237
# INFO:root:After epoch 171, Sparsity = 63.8
# After epoch 171, Reconstruction Loss = 0.2774, ASL = 0.0000,PSL = 1.5533, and total = 1.5200
# INFO:root:After epoch 172, Sparsity = 63.7
# After epoch 172, Reconstruction Loss = 0.2758, ASL = 0.0000,PSL = 1.5537, and total = 1.5187
# INFO:root:After epoch 173, Sparsity = 63.4
# After epoch 173, Reconstruction Loss = 0.2756, ASL = 0.0000,PSL = 1.5461, and total = 1.5124
# INFO:root:After epoch 174, Sparsity = 63.8
# After epoch 174, Reconstruction Loss = 0.2756, ASL = 0.0000,PSL = 1.5435, and total = 1.5104
# INFO:root:After epoch 175, Sparsity = 64.0
# After epoch 175, Reconstruction Loss = 0.2746, ASL = 0.0000,PSL = 1.5383, and total = 1.5053
# INFO:root:After epoch 176, Sparsity = 63.8
# After epoch 176, Reconstruction Loss = 0.2732, ASL = 0.0000,PSL = 1.5339, and total = 1.5004
# INFO:root:After epoch 177, Sparsity = 63.8
# After epoch 177, Reconstruction Loss = 0.2736, ASL = 0.0000,PSL = 1.5305, and total = 1.4980
# INFO:root:After epoch 178, Sparsity = 64.0
# After epoch 178, Reconstruction Loss = 0.2731, ASL = 0.0000,PSL = 1.5265, and total = 1.4943
# INFO:root:After epoch 179, Sparsity = 63.8
# After epoch 179, Reconstruction Loss = 0.2713, ASL = 0.0000,PSL = 1.5259, and total = 1.4921
# INFO:root:After epoch 180, Sparsity = 64.1
# After epoch 180, Reconstruction Loss = 0.2696, ASL = 0.0000,PSL = 1.5143, and total = 1.4810
# INFO:root:After epoch 181, Sparsity = 64.2
# After epoch 181, Reconstruction Loss = 0.2696, ASL = 0.0000,PSL = 1.5119, and total = 1.4791
# INFO:root:After epoch 182, Sparsity = 64.6
# After epoch 182, Reconstruction Loss = 0.2699, ASL = 0.0000,PSL = 1.5103, and total = 1.4781
# INFO:root:After epoch 183, Sparsity = 63.7
# After epoch 183, Reconstruction Loss = 0.2693, ASL = 0.0000,PSL = 1.5089, and total = 1.4765
# INFO:root:After epoch 184, Sparsity = 64.6
# After epoch 184, Reconstruction Loss = 0.2696, ASL = 0.0000,PSL = 1.5001, and total = 1.4697
# INFO:root:After epoch 185, Sparsity = 64.8
# After epoch 185, Reconstruction Loss = 0.2680, ASL = 0.0000,PSL = 1.4988, and total = 1.4671
# INFO:root:After epoch 186, Sparsity = 64.3
# After epoch 186, Reconstruction Loss = 0.2666, ASL = 0.0000,PSL = 1.4930, and total = 1.4610
# INFO:root:After epoch 187, Sparsity = 64.9
# After epoch 187, Reconstruction Loss = 0.2663, ASL = 0.0000,PSL = 1.4905, and total = 1.4587
# INFO:root:After epoch 188, Sparsity = 65.5
# After epoch 188, Reconstruction Loss = 0.2649, ASL = 0.0000,PSL = 1.4841, and total = 1.4522
# INFO:root:After epoch 189, Sparsity = 64.6
# After epoch 189, Reconstruction Loss = 0.2649, ASL = 0.0000,PSL = 1.4826, and total = 1.4510
# INFO:root:After epoch 190, Sparsity = 65.3
# After epoch 190, Reconstruction Loss = 0.2636, ASL = 0.0000,PSL = 1.4764, and total = 1.4447
# INFO:root:After epoch 191, Sparsity = 64.4
# After epoch 191, Reconstruction Loss = 0.2644, ASL = 0.0000,PSL = 1.4744, and total = 1.4439
# INFO:root:After epoch 192, Sparsity = 65.1
# After epoch 192, Reconstruction Loss = 0.2631, ASL = 0.0000,PSL = 1.4677, and total = 1.4372
# INFO:root:After epoch 193, Sparsity = 65.1
# After epoch 193, Reconstruction Loss = 0.2626, ASL = 0.0000,PSL = 1.4652, and total = 1.4347
# INFO:root:After epoch 194, Sparsity = 65.1
# After epoch 194, Reconstruction Loss = 0.2623, ASL = 0.0000,PSL = 1.4611, and total = 1.4311
# INFO:root:After epoch 195, Sparsity = 65.2
# After epoch 195, Reconstruction Loss = 0.2620, ASL = 0.0000,PSL = 1.4568, and total = 1.4275
# INFO:root:After epoch 196, Sparsity = 65.3
# After epoch 196, Reconstruction Loss = 0.2622, ASL = 0.0000,PSL = 1.4533, and total = 1.4249
# INFO:root:After epoch 197, Sparsity = 65.3
# After epoch 197, Reconstruction Loss = 0.2624, ASL = 0.0000,PSL = 1.4495, and total = 1.4219
# INFO:root:After epoch 198, Sparsity = 65.5
# After epoch 198, Reconstruction Loss = 0.2603, ASL = 0.0000,PSL = 1.4434, and total = 1.4150
# INFO:root:After epoch 199, Sparsity = 65.1
# After epoch 199, Reconstruction Loss = 0.2607, ASL = 0.0000,PSL = 1.4414, and total = 1.4139
# INFO:root:After epoch 200, Sparsity = 65.5
# After epoch 200, Reconstruction Loss = 0.2569, ASL = 0.0000,PSL = 1.4348, and total = 1.4048
# INFO:root:After epoch 201, Sparsity = 64.9
# After epoch 201, Reconstruction Loss = 0.2564, ASL = 0.0000,PSL = 1.4333, and total = 1.4031
# INFO:root:After epoch 202, Sparsity = 65.7
# After epoch 202, Reconstruction Loss = 0.2568, ASL = 0.0000,PSL = 1.4286, and total = 1.3996
# INFO:root:After epoch 203, Sparsity = 65.6
# After epoch 203, Reconstruction Loss = 0.2572, ASL = 0.0000,PSL = 1.4245, and total = 1.3968
# INFO:root:After epoch 204, Sparsity = 65.4
# After epoch 204, Reconstruction Loss = 0.2554, ASL = 0.0000,PSL = 1.4210, and total = 1.3922
# INFO:root:After epoch 205, Sparsity = 65.4
# After epoch 205, Reconstruction Loss = 0.2563, ASL = 0.0000,PSL = 1.4157, and total = 1.3888
# INFO:root:After epoch 206, Sparsity = 66.7
# After epoch 206, Reconstruction Loss = 0.2557, ASL = 0.0000,PSL = 1.4076, and total = 1.3818
# INFO:root:After epoch 207, Sparsity = 65.7
# After epoch 207, Reconstruction Loss = 0.2546, ASL = 0.0000,PSL = 1.4105, and total = 1.3830
# INFO:root:After epoch 208, Sparsity = 66.1
# After epoch 208, Reconstruction Loss = 0.2543, ASL = 0.0000,PSL = 1.4058, and total = 1.3790
# INFO:root:After epoch 209, Sparsity = 66.6
# After epoch 209, Reconstruction Loss = 0.2541, ASL = 0.0000,PSL = 1.3998, and total = 1.3740
# INFO:root:After epoch 210, Sparsity = 66.3
# After epoch 210, Reconstruction Loss = 0.2535, ASL = 0.0000,PSL = 1.3971, and total = 1.3712
# INFO:root:After epoch 211, Sparsity = 66.3
# After epoch 211, Reconstruction Loss = 0.2523, ASL = 0.0000,PSL = 1.3933, and total = 1.3669
# INFO:root:After epoch 212, Sparsity = 66.1
# After epoch 212, Reconstruction Loss = 0.2516, ASL = 0.0000,PSL = 1.3901, and total = 1.3638
# INFO:root:After epoch 213, Sparsity = 67.1
# After epoch 213, Reconstruction Loss = 0.2517, ASL = 0.0000,PSL = 1.3828, and total = 1.3580
# INFO:root:After epoch 214, Sparsity = 66.3
# After epoch 214, Reconstruction Loss = 0.2526, ASL = 0.0000,PSL = 1.3844, and total = 1.3601
# INFO:root:After epoch 215, Sparsity = 66.7
# After epoch 215, Reconstruction Loss = 0.2489, ASL = 0.0000,PSL = 1.3741, and total = 1.3482
# INFO:root:After epoch 216, Sparsity = 66.6
# After epoch 216, Reconstruction Loss = 0.2488, ASL = 0.0000,PSL = 1.3750, and total = 1.3488
# INFO:root:After epoch 217, Sparsity = 66.8
# After epoch 217, Reconstruction Loss = 0.2482, ASL = 0.0000,PSL = 1.3711, and total = 1.3451
# INFO:root:After epoch 218, Sparsity = 67.0
# After epoch 218, Reconstruction Loss = 0.2495, ASL = 0.0000,PSL = 1.3667, and total = 1.3428
# INFO:root:After epoch 219, Sparsity = 66.9
# After epoch 219, Reconstruction Loss = 0.2488, ASL = 0.0000,PSL = 1.3618, and total = 1.3382
# INFO:root:After epoch 220, Sparsity = 67.2
# After epoch 220, Reconstruction Loss = 0.2480, ASL = 0.0000,PSL = 1.3576, and total = 1.3341
# INFO:root:After epoch 221, Sparsity = 67.6
# After epoch 221, Reconstruction Loss = 0.2492, ASL = 0.0000,PSL = 1.3547, and total = 1.3330
# INFO:root:After epoch 222, Sparsity = 67.1
# After epoch 222, Reconstruction Loss = 0.2469, ASL = 0.0000,PSL = 1.3514, and total = 1.3280
# INFO:root:After epoch 223, Sparsity = 67.6
# After epoch 223, Reconstruction Loss = 0.2477, ASL = 0.0000,PSL = 1.3479, and total = 1.3260
# INFO:root:After epoch 224, Sparsity = 66.9
# After epoch 224, Reconstruction Loss = 0.2450, ASL = 0.0000,PSL = 1.3433, and total = 1.3197
# INFO:root:After epoch 225, Sparsity = 66.8
# After epoch 225, Reconstruction Loss = 0.2446, ASL = 0.0000,PSL = 1.3393, and total = 1.3160
# INFO:root:After epoch 226, Sparsity = 68.3
# After epoch 226, Reconstruction Loss = 0.2456, ASL = 0.0000,PSL = 1.3341, and total = 1.3128
# INFO:root:After epoch 227, Sparsity = 67.6
# After epoch 227, Reconstruction Loss = 0.2432, ASL = 0.0000,PSL = 1.3301, and total = 1.3073
# INFO:root:After epoch 228, Sparsity = 67.4
# After epoch 228, Reconstruction Loss = 0.2439, ASL = 0.0000,PSL = 1.3260, and total = 1.3046
# INFO:root:After epoch 229, Sparsity = 67.5
# After epoch 229, Reconstruction Loss = 0.2439, ASL = 0.0000,PSL = 1.3254, and total = 1.3042
# INFO:root:After epoch 230, Sparsity = 67.7
# After epoch 230, Reconstruction Loss = 0.2434, ASL = 0.0000,PSL = 1.3215, and total = 1.3006
# INFO:root:After epoch 231, Sparsity = 67.9
# After epoch 231, Reconstruction Loss = 0.2435, ASL = 0.0000,PSL = 1.3149, and total = 1.2954
# INFO:root:After epoch 232, Sparsity = 67.6
# After epoch 232, Reconstruction Loss = 0.2430, ASL = 0.0000,PSL = 1.3153, and total = 1.2953
# INFO:root:After epoch 233, Sparsity = 68.2
# After epoch 233, Reconstruction Loss = 0.2418, ASL = 0.0000,PSL = 1.3083, and total = 1.2884
# INFO:root:After epoch 234, Sparsity = 68.0
# After epoch 234, Reconstruction Loss = 0.2405, ASL = 0.0000,PSL = 1.3071, and total = 1.2862
# INFO:root:After epoch 235, Sparsity = 68.3
# After epoch 235, Reconstruction Loss = 0.2395, ASL = 0.0000,PSL = 1.3007, and total = 1.2801
# INFO:root:After epoch 236, Sparsity = 67.5
# After epoch 236, Reconstruction Loss = 0.2399, ASL = 0.0000,PSL = 1.2991, and total = 1.2792
# INFO:root:After epoch 237, Sparsity = 68.4
# After epoch 237, Reconstruction Loss = 0.2403, ASL = 0.0000,PSL = 1.2921, and total = 1.2740
# INFO:root:After epoch 238, Sparsity = 68.3
# After epoch 238, Reconstruction Loss = 0.2391, ASL = 0.0000,PSL = 1.2913, and total = 1.2721
# INFO:root:After epoch 239, Sparsity = 68.1
# After epoch 239, Reconstruction Loss = 0.2383, ASL = 0.0000,PSL = 1.2849, and total = 1.2662
# INFO:root:After epoch 240, Sparsity = 68.3
# After epoch 240, Reconstruction Loss = 0.2389, ASL = 0.0000,PSL = 1.2821, and total = 1.2645
# INFO:root:After epoch 241, Sparsity = 68.6
# After epoch 241, Reconstruction Loss = 0.2372, ASL = 0.0000,PSL = 1.2773, and total = 1.2590
# INFO:root:After epoch 242, Sparsity = 68.8
# After epoch 242, Reconstruction Loss = 0.2368, ASL = 0.0000,PSL = 1.2752, and total = 1.2569
# INFO:root:After epoch 243, Sparsity = 69.1
# After epoch 243, Reconstruction Loss = 0.2397, ASL = 0.0000,PSL = 1.2713, and total = 1.2567
# INFO:root:After epoch 244, Sparsity = 69.0
# After epoch 244, Reconstruction Loss = 0.2374, ASL = 0.0000,PSL = 1.2679, and total = 1.2518
# INFO:root:After epoch 245, Sparsity = 68.8
# After epoch 245, Reconstruction Loss = 0.2363, ASL = 0.0000,PSL = 1.2646, and total = 1.2480
# INFO:root:After epoch 246, Sparsity = 68.5
# After epoch 246, Reconstruction Loss = 0.2347, ASL = 0.0000,PSL = 1.2599, and total = 1.2427
# INFO:root:After epoch 247, Sparsity = 69.0
# After epoch 247, Reconstruction Loss = 0.2353, ASL = 0.0000,PSL = 1.2539, and total = 1.2384
# INFO:root:After epoch 248, Sparsity = 69.4
# After epoch 248, Reconstruction Loss = 0.2351, ASL = 0.0000,PSL = 1.2538, and total = 1.2381
# INFO:root:After epoch 249, Sparsity = 68.9
# After epoch 249, Reconstruction Loss = 0.2346, ASL = 0.0000,PSL = 1.2491, and total = 1.2339
# INFO:root:After epoch 250, Sparsity = 69.4
# After epoch 250, Reconstruction Loss = 0.2358, ASL = 0.0000,PSL = 1.2458, and total = 1.2325
# INFO:root:After epoch 251, Sparsity = 68.5
# After epoch 251, Reconstruction Loss = 0.2329, ASL = 0.0000,PSL = 1.2413, and total = 1.2259
# INFO:root:After epoch 252, Sparsity = 69.0
# After epoch 252, Reconstruction Loss = 0.2329, ASL = 0.0000,PSL = 1.2374, and total = 1.2229
# INFO:root:After epoch 253, Sparsity = 69.4
# After epoch 253, Reconstruction Loss = 0.2334, ASL = 0.0000,PSL = 1.2362, and total = 1.2224
# INFO:root:After epoch 254, Sparsity = 68.8
# After epoch 254, Reconstruction Loss = 0.2330, ASL = 0.0000,PSL = 1.2308, and total = 1.2176
# INFO:root:After epoch 255, Sparsity = 69.9
# After epoch 255, Reconstruction Loss = 0.2334, ASL = 0.0000,PSL = 1.2274, and total = 1.2153
# INFO:root:After epoch 256, Sparsity = 69.4
# After epoch 256, Reconstruction Loss = 0.2327, ASL = 0.0000,PSL = 1.2244, and total = 1.2122
# INFO:root:After epoch 257, Sparsity = 69.7
# After epoch 257, Reconstruction Loss = 0.2308, ASL = 0.0000,PSL = 1.2190, and total = 1.2060
# INFO:root:After epoch 258, Sparsity = 69.1
# After epoch 258, Reconstruction Loss = 0.2296, ASL = 0.0000,PSL = 1.2163, and total = 1.2026
# INFO:root:After epoch 259, Sparsity = 70.1
# After epoch 259, Reconstruction Loss = 0.2303, ASL = 0.0000,PSL = 1.2113, and total = 1.1994
# INFO:root:After epoch 260, Sparsity = 70.0
# After epoch 260, Reconstruction Loss = 0.2304, ASL = 0.0000,PSL = 1.2078, and total = 1.1967
# INFO:root:After epoch 261, Sparsity = 69.2
# After epoch 261, Reconstruction Loss = 0.2287, ASL = 0.0000,PSL = 1.2068, and total = 1.1942
# INFO:root:After epoch 262, Sparsity = 70.0
# After epoch 262, Reconstruction Loss = 0.2317, ASL = 0.0000,PSL = 1.2035, and total = 1.1945
# INFO:root:After epoch 263, Sparsity = 70.7
# After epoch 263, Reconstruction Loss = 0.2281, ASL = 0.0000,PSL = 1.1970, and total = 1.1857
# INFO:root:After epoch 264, Sparsity = 70.1
# After epoch 264, Reconstruction Loss = 0.2278, ASL = 0.0000,PSL = 1.1943, and total = 1.1832
# INFO:root:After epoch 265, Sparsity = 70.1
# After epoch 265, Reconstruction Loss = 0.2271, ASL = 0.0000,PSL = 1.1910, and total = 1.1798
# INFO:root:After epoch 266, Sparsity = 70.7
# After epoch 266, Reconstruction Loss = 0.2285, ASL = 0.0000,PSL = 1.1885, and total = 1.1792
# INFO:root:After epoch 267, Sparsity = 69.6
# After epoch 267, Reconstruction Loss = 0.2274, ASL = 0.0000,PSL = 1.1848, and total = 1.1752
# INFO:root:After epoch 268, Sparsity = 70.5
# After epoch 268, Reconstruction Loss = 0.2269, ASL = 0.0000,PSL = 1.1805, and total = 1.1713
# INFO:root:After epoch 269, Sparsity = 71.2
# After epoch 269, Reconstruction Loss = 0.2261, ASL = 0.0000,PSL = 1.1765, and total = 1.1673
# INFO:root:After epoch 270, Sparsity = 70.7
# After epoch 270, Reconstruction Loss = 0.2264, ASL = 0.0000,PSL = 1.1721, and total = 1.1640
# INFO:root:After epoch 271, Sparsity = 70.6
# After epoch 271, Reconstruction Loss = 0.2266, ASL = 0.0000,PSL = 1.1712, and total = 1.1635
# INFO:root:After epoch 272, Sparsity = 69.7
# After epoch 272, Reconstruction Loss = 0.2252, ASL = 0.0000,PSL = 1.1690, and total = 1.1604
# INFO:root:After epoch 273, Sparsity = 70.6
# After epoch 273, Reconstruction Loss = 0.2248, ASL = 0.0000,PSL = 1.1647, and total = 1.1566
# INFO:root:After epoch 274, Sparsity = 70.6
# After epoch 274, Reconstruction Loss = 0.2258, ASL = 0.0000,PSL = 1.1616, and total = 1.1551
# INFO:root:After epoch 275, Sparsity = 71.2
# After epoch 275, Reconstruction Loss = 0.2261, ASL = 0.0000,PSL = 1.1558, and total = 1.1507
# INFO:root:After epoch 276, Sparsity = 71.3
# After epoch 276, Reconstruction Loss = 0.2237, ASL = 0.0000,PSL = 1.1539, and total = 1.1468
# INFO:root:After epoch 277, Sparsity = 70.9
# After epoch 277, Reconstruction Loss = 0.2234, ASL = 0.0000,PSL = 1.1516, and total = 1.1447
# INFO:root:After epoch 278, Sparsity = 71.0
# After epoch 278, Reconstruction Loss = 0.2243, ASL = 0.0000,PSL = 1.1489, and total = 1.1434
# INFO:root:After epoch 279, Sparsity = 71.1
# After epoch 279, Reconstruction Loss = 0.2220, ASL = 0.0000,PSL = 1.1438, and total = 1.1371
# INFO:root:After epoch 280, Sparsity = 70.9
# After epoch 280, Reconstruction Loss = 0.2220, ASL = 0.0000,PSL = 1.1382, and total = 1.1326
# INFO:root:After epoch 281, Sparsity = 71.5
# After epoch 281, Reconstruction Loss = 0.2222, ASL = 0.0000,PSL = 1.1353, and total = 1.1305
# INFO:root:After epoch 282, Sparsity = 71.2
# After epoch 282, Reconstruction Loss = 0.2216, ASL = 0.0000,PSL = 1.1308, and total = 1.1262
# INFO:root:After epoch 283, Sparsity = 71.2
# After epoch 283, Reconstruction Loss = 0.2239, ASL = 0.0000,PSL = 1.1303, and total = 1.1282
# INFO:root:After epoch 284, Sparsity = 70.8
# After epoch 284, Reconstruction Loss = 0.2215, ASL = 0.0000,PSL = 1.1306, and total = 1.1259
# INFO:root:After epoch 285, Sparsity = 71.4
# After epoch 285, Reconstruction Loss = 0.2199, ASL = 0.0000,PSL = 1.1223, and total = 1.1177
# INFO:root:After epoch 286, Sparsity = 72.0
# After epoch 286, Reconstruction Loss = 0.2207, ASL = 0.0000,PSL = 1.1179, and total = 1.1150
# INFO:root:After epoch 287, Sparsity = 71.5
# After epoch 287, Reconstruction Loss = 0.2207, ASL = 0.0000,PSL = 1.1184, and total = 1.1154
# INFO:root:After epoch 288, Sparsity = 71.7
# After epoch 288, Reconstruction Loss = 0.2199, ASL = 0.0000,PSL = 1.1107, and total = 1.1085
# INFO:root:After epoch 289, Sparsity = 71.5
# After epoch 289, Reconstruction Loss = 0.2193, ASL = 0.0000,PSL = 1.1099, and total = 1.1073
# INFO:root:After epoch 290, Sparsity = 71.9
# After epoch 290, Reconstruction Loss = 0.2191, ASL = 0.0000,PSL = 1.1052, and total = 1.1032
# INFO:root:After epoch 291, Sparsity = 71.4
# After epoch 291, Reconstruction Loss = 0.2176, ASL = 0.0000,PSL = 1.0999, and total = 1.0975
# INFO:root:After epoch 292, Sparsity = 72.2
# After epoch 292, Reconstruction Loss = 0.2178, ASL = 0.0000,PSL = 1.0988, and total = 1.0968
# INFO:root:After epoch 293, Sparsity = 71.8
# After epoch 293, Reconstruction Loss = 0.2177, ASL = 0.0000,PSL = 1.0939, and total = 1.0929
# INFO:root:After epoch 294, Sparsity = 72.9
# After epoch 294, Reconstruction Loss = 0.2174, ASL = 0.0000,PSL = 1.0917, and total = 1.0908
# INFO:root:After epoch 295, Sparsity = 73.0
# After epoch 295, Reconstruction Loss = 0.2177, ASL = 0.0000,PSL = 1.0860, and total = 1.0865
# INFO:root:After epoch 296, Sparsity = 72.3
# After epoch 296, Reconstruction Loss = 0.2177, ASL = 0.0000,PSL = 1.0860, and total = 1.0865
# INFO:root:After epoch 297, Sparsity = 72.3
# After epoch 297, Reconstruction Loss = 0.2166, ASL = 0.0000,PSL = 1.0800, and total = 1.0806
# INFO:root:After epoch 298, Sparsity = 71.5
# After epoch 298, Reconstruction Loss = 0.2157, ASL = 0.0000,PSL = 1.0801, and total = 1.0798
# INFO:root:After epoch 299, Sparsity = 72.2
# After epoch 299, Reconstruction Loss = 0.2159, ASL = 0.0000,PSL = 1.0737, and total = 1.0749
# INFO:root:After epoch 300, Sparsity = 72.1
# After epoch 300, Reconstruction Loss = 0.2157, ASL = 0.0000,PSL = 1.0728, and total = 1.0739
# INFO:root:After epoch 301, Sparsity = 72.4
# After epoch 301, Reconstruction Loss = 0.2148, ASL = 0.0000,PSL = 1.0686, and total = 1.0697
# INFO:root:After epoch 302, Sparsity = 72.4
# After epoch 302, Reconstruction Loss = 0.2140, ASL = 0.0000,PSL = 1.0662, and total = 1.0670
# INFO:root:After epoch 303, Sparsity = 72.7
# After epoch 303, Reconstruction Loss = 0.2137, ASL = 0.0000,PSL = 1.0627, and total = 1.0639
# INFO:root:After epoch 304, Sparsity = 72.7
# After epoch 304, Reconstruction Loss = 0.2138, ASL = 0.0000,PSL = 1.0577, and total = 1.0599
# INFO:root:After epoch 305, Sparsity = 72.9
# After epoch 305, Reconstruction Loss = 0.2138, ASL = 0.0000,PSL = 1.0581, and total = 1.0603
# INFO:root:After epoch 306, Sparsity = 72.4
# After epoch 306, Reconstruction Loss = 0.2143, ASL = 0.0000,PSL = 1.0569, and total = 1.0599
# INFO:root:After epoch 307, Sparsity = 72.7
# After epoch 307, Reconstruction Loss = 0.2130, ASL = 0.0000,PSL = 1.0494, and total = 1.0526
# INFO:root:After epoch 308, Sparsity = 72.3
# After epoch 308, Reconstruction Loss = 0.2124, ASL = 0.0000,PSL = 1.0478, and total = 1.0506
# INFO:root:After epoch 309, Sparsity = 73.3
# After epoch 309, Reconstruction Loss = 0.2128, ASL = 0.0000,PSL = 1.0424, and total = 1.0467
# INFO:root:After epoch 310, Sparsity = 72.9
# After epoch 310, Reconstruction Loss = 0.2139, ASL = 0.0000,PSL = 1.0388, and total = 1.0450
# INFO:root:After epoch 311, Sparsity = 72.5
# After epoch 311, Reconstruction Loss = 0.2153, ASL = 0.0000,PSL = 1.0407, and total = 1.0479
# INFO:root:After epoch 312, Sparsity = 72.7
# After epoch 312, Reconstruction Loss = 0.2115, ASL = 0.0000,PSL = 1.0349, and total = 1.0395
# INFO:root:After epoch 313, Sparsity = 72.5
# After epoch 313, Reconstruction Loss = 0.2119, ASL = 0.0000,PSL = 1.0330, and total = 1.0383
# INFO:root:After epoch 314, Sparsity = 73.7
# After epoch 314, Reconstruction Loss = 0.2105, ASL = 0.0000,PSL = 1.0272, and total = 1.0323
# INFO:root:After epoch 315, Sparsity = 73.4
# After epoch 315, Reconstruction Loss = 0.2106, ASL = 0.0000,PSL = 1.0240, and total = 1.0298
# INFO:root:After epoch 316, Sparsity = 73.1
# After epoch 316, Reconstruction Loss = 0.2109, ASL = 0.0000,PSL = 1.0217, and total = 1.0283
# INFO:root:After epoch 317, Sparsity = 73.2
# After epoch 317, Reconstruction Loss = 0.2116, ASL = 0.0000,PSL = 1.0176, and total = 1.0257
# INFO:root:After epoch 318, Sparsity = 73.7
# After epoch 318, Reconstruction Loss = 0.2102, ASL = 0.0000,PSL = 1.0136, and total = 1.0210
# INFO:root:After epoch 319, Sparsity = 74.0
# After epoch 319, Reconstruction Loss = 0.2115, ASL = 0.0000,PSL = 1.0107, and total = 1.0201
# INFO:root:After epoch 320, Sparsity = 73.3
# After epoch 320, Reconstruction Loss = 0.2096, ASL = 0.0000,PSL = 1.0099, and total = 1.0174
# INFO:root:After epoch 321, Sparsity = 73.9
# After epoch 321, Reconstruction Loss = 0.2078, ASL = 0.0000,PSL = 1.0051, and total = 1.0119
# INFO:root:After epoch 322, Sparsity = 73.4
# After epoch 322, Reconstruction Loss = 0.2100, ASL = 0.0000,PSL = 1.0022, and total = 1.0117
# INFO:root:After epoch 323, Sparsity = 74.0
# After epoch 323, Reconstruction Loss = 0.2098, ASL = 0.0000,PSL = 0.9971, and total = 1.0075
# INFO:root:After epoch 324, Sparsity = 73.9
# After epoch 324, Reconstruction Loss = 0.2072, ASL = 0.0000,PSL = 0.9980, and total = 1.0056
# INFO:root:After epoch 325, Sparsity = 73.8
# After epoch 325, Reconstruction Loss = 0.2087, ASL = 0.0000,PSL = 0.9937, and total = 1.0037
# INFO:root:After epoch 326, Sparsity = 73.9
# After epoch 326, Reconstruction Loss = 0.2077, ASL = 0.0000,PSL = 0.9877, and total = 0.9979
# INFO:root:After epoch 327, Sparsity = 73.3
# After epoch 327, Reconstruction Loss = 0.2086, ASL = 0.0000,PSL = 0.9911, and total = 1.0015
# INFO:root:After epoch 328, Sparsity = 73.9
# After epoch 328, Reconstruction Loss = 0.2071, ASL = 0.0000,PSL = 0.9837, and total = 0.9941
# INFO:root:After epoch 329, Sparsity = 74.0
# After epoch 329, Reconstruction Loss = 0.2071, ASL = 0.0000,PSL = 0.9836, and total = 0.9940
# INFO:root:After epoch 330, Sparsity = 74.3
# After epoch 330, Reconstruction Loss = 0.2064, ASL = 0.0000,PSL = 0.9770, and total = 0.9880
# INFO:root:After epoch 331, Sparsity = 74.1
# After epoch 331, Reconstruction Loss = 0.2058, ASL = 0.0000,PSL = 0.9746, and total = 0.9855
# INFO:root:After epoch 332, Sparsity = 75.1
# After epoch 332, Reconstruction Loss = 0.2065, ASL = 0.0000,PSL = 0.9660, and total = 0.9793
# INFO:root:After epoch 333, Sparsity = 73.4
# After epoch 333, Reconstruction Loss = 0.2050, ASL = 0.0000,PSL = 0.9668, and total = 0.9784
# INFO:root:After epoch 334, Sparsity = 74.8
# After epoch 334, Reconstruction Loss = 0.2052, ASL = 0.0000,PSL = 0.9637, and total = 0.9761
# INFO:root:After epoch 335, Sparsity = 74.1
# After epoch 335, Reconstruction Loss = 0.2051, ASL = 0.0000,PSL = 0.9629, and total = 0.9755
# INFO:root:After epoch 336, Sparsity = 74.2
# After epoch 336, Reconstruction Loss = 0.2063, ASL = 0.0000,PSL = 0.9599, and total = 0.9742
# INFO:root:After epoch 337, Sparsity = 75.1
# After epoch 337, Reconstruction Loss = 0.2051, ASL = 0.0000,PSL = 0.9559, and total = 0.9698
# INFO:root:After epoch 338, Sparsity = 74.1
# After epoch 338, Reconstruction Loss = 0.2044, ASL = 0.0000,PSL = 0.9517, and total = 0.9657
# INFO:root:After epoch 339, Sparsity = 75.4
# After epoch 339, Reconstruction Loss = 0.2050, ASL = 0.0000,PSL = 0.9496, and total = 0.9647
# INFO:root:After epoch 340, Sparsity = 74.4
# After epoch 340, Reconstruction Loss = 0.2033, ASL = 0.0000,PSL = 0.9462, and total = 0.9602
# INFO:root:After epoch 341, Sparsity = 74.8
# After epoch 341, Reconstruction Loss = 0.2041, ASL = 0.0000,PSL = 0.9438, and total = 0.9592
# INFO:root:After epoch 342, Sparsity = 74.4
# After epoch 342, Reconstruction Loss = 0.2041, ASL = 0.0000,PSL = 0.9410, and total = 0.9569
# INFO:root:After epoch 343, Sparsity = 75.2
# After epoch 343, Reconstruction Loss = 0.2028, ASL = 0.0000,PSL = 0.9401, and total = 0.9549
# INFO:root:After epoch 344, Sparsity = 75.4
# After epoch 344, Reconstruction Loss = 0.2035, ASL = 0.0000,PSL = 0.9351, and total = 0.9516
# INFO:root:After epoch 345, Sparsity = 74.9
# After epoch 345, Reconstruction Loss = 0.2017, ASL = 0.0000,PSL = 0.9343, and total = 0.9491
# INFO:root:After epoch 346, Sparsity = 75.1
# After epoch 346, Reconstruction Loss = 0.2020, ASL = 0.0000,PSL = 0.9257, and total = 0.9426
# INFO:root:After epoch 347, Sparsity = 75.1
# After epoch 347, Reconstruction Loss = 0.2016, ASL = 0.0000,PSL = 0.9266, and total = 0.9428
# INFO:root:After epoch 348, Sparsity = 75.1
# After epoch 348, Reconstruction Loss = 0.2015, ASL = 0.0000,PSL = 0.9252, and total = 0.9416
# INFO:root:After epoch 349, Sparsity = 75.3
# After epoch 349, Reconstruction Loss = 0.2005, ASL = 0.0000,PSL = 0.9197, and total = 0.9362
# INFO:root:After epoch 350, Sparsity = 75.1
# After epoch 350, Reconstruction Loss = 0.2029, ASL = 0.0000,PSL = 0.9185, and total = 0.9377
# INFO:root:After epoch 351, Sparsity = 75.5
# After epoch 351, Reconstruction Loss = 0.2013, ASL = 0.0000,PSL = 0.9154, and total = 0.9337
# ...
# INFO:root:After epoch 685, Sparsity = 89.5
# After epoch 685, Reconstruction Loss = 0.1595, ASL = 0.0000,PSL = 0.3060, and total = 0.4044
# INFO:root:After epoch 686, Sparsity = 88.6
# After epoch 686, Reconstruction Loss = 0.1575, ASL = 0.0000,PSL = 0.3066, and total = 0.4028
# INFO:root:After epoch 687, Sparsity = 89.5
# After epoch 687, Reconstruction Loss = 0.1589, ASL = 0.0000,PSL = 0.3032, and total = 0.4015
# INFO:root:After epoch 688, Sparsity = 89.5
# After epoch 688, Reconstruction Loss = 0.1569, ASL = 0.0000,PSL = 0.3018, and total = 0.3983
# INFO:root:After epoch 689, Sparsity = 88.6
# After epoch 689, Reconstruction Loss = 0.1577, ASL = 0.0000,PSL = 0.3040, and total = 0.4009
# INFO:root:After epoch 690, Sparsity = 90.0
# After epoch 690, Reconstruction Loss = 0.1588, ASL = 0.0000,PSL = 0.3005, and total = 0.3992
# INFO:root:After epoch 691, Sparsity = 88.8
# After epoch 691, Reconstruction Loss = 0.1563, ASL = 0.0000,PSL = 0.2977, and total = 0.3945
# INFO:root:After epoch 692, Sparsity = 89.6
# After epoch 692, Reconstruction Loss = 0.1580, ASL = 0.0000,PSL = 0.2967, and total = 0.3953
# INFO:root:After epoch 693, Sparsity = 88.9
# After epoch 693, Reconstruction Loss = 0.1589, ASL = 0.0000,PSL = 0.2979, and total = 0.3973
# INFO:root:After epoch 694, Sparsity = 89.7
# After epoch 694, Reconstruction Loss = 0.1577, ASL = 0.0000,PSL = 0.2974, and total = 0.3956
# INFO:root:After epoch 695, Sparsity = 89.3
# After epoch 695, Reconstruction Loss = 0.1574, ASL = 0.0000,PSL = 0.2964, and total = 0.3945
# INFO:root:After epoch 696, Sparsity = 89.3
# After epoch 696, Reconstruction Loss = 0.1567, ASL = 0.0000,PSL = 0.2972, and total = 0.3945
# INFO:root:After epoch 697, Sparsity = 89.9
# After epoch 697, Reconstruction Loss = 0.1562, ASL = 0.0000,PSL = 0.2933, and total = 0.3908
# INFO:root:After epoch 698, Sparsity = 89.6
# After epoch 698, Reconstruction Loss = 0.1576, ASL = 0.0000,PSL = 0.2925, and total = 0.3916
# INFO:root:After epoch 699, Sparsity = 89.8
# After epoch 699, Reconstruction Loss = 0.1574, ASL = 0.0000,PSL = 0.2914, and total = 0.3904
# INFO:root:After epoch 700, Sparsity = 89.7
# After epoch 700, Reconstruction Loss = 0.1564, ASL = 0.0000,PSL = 0.2911, and total = 0.3892
# INFO:root:After epoch 701, Sparsity = 89.3
# After epoch 701, Reconstruction Loss = 0.1561, ASL = 0.0000,PSL = 0.2909, and total = 0.3888
# INFO:root:After epoch 702, Sparsity = 90.1
# After epoch 702, Reconstruction Loss = 0.1575, ASL = 0.0000,PSL = 0.2880, and total = 0.3880
# INFO:root:After epoch 703, Sparsity = 89.8
# After epoch 703, Reconstruction Loss = 0.1561, ASL = 0.0000,PSL = 0.2893, and total = 0.3875
# INFO:root:After epoch 704, Sparsity = 89.7
# After epoch 704, Reconstruction Loss = 0.1574, ASL = 0.0000,PSL = 0.2870, and total = 0.3870
# INFO:root:After epoch 705, Sparsity = 90.0
# After epoch 705, Reconstruction Loss = 0.1576, ASL = 0.0000,PSL = 0.2868, and total = 0.3871
# INFO:root:After epoch 706, Sparsity = 90.2
# After epoch 706, Reconstruction Loss = 0.1571, ASL = 0.0000,PSL = 0.2857, and total = 0.3856
# INFO:root:After epoch 707, Sparsity = 89.2
# After epoch 707, Reconstruction Loss = 0.1558, ASL = 0.0000,PSL = 0.2857, and total = 0.3843
# INFO:root:After epoch 708, Sparsity = 89.9
# After epoch 708, Reconstruction Loss = 0.1564, ASL = 0.0000,PSL = 0.2843, and total = 0.3839
# INFO:root:After epoch 709, Sparsity = 89.6
# After epoch 709, Reconstruction Loss = 0.1563, ASL = 0.0000,PSL = 0.2826, and total = 0.3824
# INFO:root:After epoch 710, Sparsity = 89.8
# After epoch 710, Reconstruction Loss = 0.1557, ASL = 0.0000,PSL = 0.2821, and total = 0.3813
# INFO:root:After epoch 711, Sparsity = 90.1
# After epoch 711, Reconstruction Loss = 0.1560, ASL = 0.0000,PSL = 0.2802, and total = 0.3801
# INFO:root:After epoch 712, Sparsity = 90.3
# After epoch 712, Reconstruction Loss = 0.1579, ASL = 0.0000,PSL = 0.2795, and total = 0.3815
# INFO:root:After epoch 713, Sparsity = 89.8
# After epoch 713, Reconstruction Loss = 0.1570, ASL = 0.0000,PSL = 0.2790, and total = 0.3801
# INFO:root:After epoch 714, Sparsity = 90.2
# After epoch 714, Reconstruction Loss = 0.1562, ASL = 0.0000,PSL = 0.2779, and total = 0.3785
# INFO:root:After epoch 715, Sparsity = 90.2
# After epoch 715, Reconstruction Loss = 0.1569, ASL = 0.0000,PSL = 0.2770, and total = 0.3785
# INFO:root:After epoch 716, Sparsity = 90.5
# After epoch 716, Reconstruction Loss = 0.1560, ASL = 0.0000,PSL = 0.2769, and total = 0.3776
# INFO:root:After epoch 717, Sparsity = 90.0
# After epoch 717, Reconstruction Loss = 0.1556, ASL = 0.0000,PSL = 0.2752, and total = 0.3758
# INFO:root:After epoch 718, Sparsity = 90.5
# After epoch 718, Reconstruction Loss = 0.1554, ASL = 0.0000,PSL = 0.2750, and total = 0.3754
# INFO:root:After epoch 719, Sparsity = 90.0
# After epoch 719, Reconstruction Loss = 0.1565, ASL = 0.0000,PSL = 0.2739, and total = 0.3756
# INFO:root:After epoch 720, Sparsity = 90.2
# After epoch 720, Reconstruction Loss = 0.1566, ASL = 0.0000,PSL = 0.2741, and total = 0.3758
# INFO:root:After epoch 721, Sparsity = 90.7
# After epoch 721, Reconstruction Loss = 0.1563, ASL = 0.0000,PSL = 0.2726, and total = 0.3744
# INFO:root:After epoch 722, Sparsity = 89.9
# After epoch 722, Reconstruction Loss = 0.1560, ASL = 0.0000,PSL = 0.2707, and total = 0.3726
# INFO:root:After epoch 723, Sparsity = 90.2
# After epoch 723, Reconstruction Loss = 0.1561, ASL = 0.0000,PSL = 0.2709, and total = 0.3729
# INFO:root:After epoch 724, Sparsity = 90.1
# After epoch 724, Reconstruction Loss = 0.1571, ASL = 0.0000,PSL = 0.2714, and total = 0.3743
# INFO:root:After epoch 725, Sparsity = 89.7
# After epoch 725, Reconstruction Loss = 0.1580, ASL = 0.0000,PSL = 0.2688, and total = 0.3730
# INFO:root:After epoch 726, Sparsity = 91.2
# After epoch 726, Reconstruction Loss = 0.1575, ASL = 0.0000,PSL = 0.2689, and total = 0.3726
# INFO:root:After epoch 727, Sparsity = 90.4
# After epoch 727, Reconstruction Loss = 0.1553, ASL = 0.0000,PSL = 0.2669, and total = 0.3688
# INFO:root:After epoch 728, Sparsity = 90.3
# After epoch 728, Reconstruction Loss = 0.1564, ASL = 0.0000,PSL = 0.2666, and total = 0.3697
# INFO:root:After epoch 729, Sparsity = 90.3
# After epoch 729, Reconstruction Loss = 0.1582, ASL = 0.0000,PSL = 0.2660, and total = 0.3710
# INFO:root:After epoch 730, Sparsity = 90.5
# After epoch 730, Reconstruction Loss = 0.1548, ASL = 0.0000,PSL = 0.2651, and total = 0.3668
# INFO:root:After epoch 731, Sparsity = 90.4
# After epoch 731, Reconstruction Loss = 0.1546, ASL = 0.0000,PSL = 0.2641, and total = 0.3659
# INFO:root:After epoch 732, Sparsity = 90.1
# After epoch 732, Reconstruction Loss = 0.1549, ASL = 0.0000,PSL = 0.2630, and total = 0.3654
# INFO:root:After epoch 733, Sparsity = 90.9
# After epoch 733, Reconstruction Loss = 0.1555, ASL = 0.0000,PSL = 0.2622, and total = 0.3652
# INFO:root:After epoch 734, Sparsity = 90.6
# After epoch 734, Reconstruction Loss = 0.1549, ASL = 0.0000,PSL = 0.2628, and total = 0.3652
# INFO:root:After epoch 735, Sparsity = 90.6
# After epoch 735, Reconstruction Loss = 0.1552, ASL = 0.0000,PSL = 0.2610, and total = 0.3641
# INFO:root:After epoch 736, Sparsity = 90.7
# After epoch 736, Reconstruction Loss = 0.1562, ASL = 0.0000,PSL = 0.2609, and total = 0.3649
# INFO:root:After epoch 737, Sparsity = 90.4
# After epoch 737, Reconstruction Loss = 0.1543, ASL = 0.0000,PSL = 0.2604, and total = 0.3627
# INFO:root:After epoch 738, Sparsity = 90.6
# After epoch 738, Reconstruction Loss = 0.1575, ASL = 0.0000,PSL = 0.2586, and total = 0.3644
# INFO:root:After epoch 739, Sparsity = 90.5
# After epoch 739, Reconstruction Loss = 0.1542, ASL = 0.0000,PSL = 0.2573, and total = 0.3600
# INFO:root:After epoch 740, Sparsity = 90.2
# After epoch 740, Reconstruction Loss = 0.1548, ASL = 0.0000,PSL = 0.2573, and total = 0.3606
# INFO:root:After epoch 741, Sparsity = 91.3
# After epoch 741, Reconstruction Loss = 0.1548, ASL = 0.0000,PSL = 0.2543, and total = 0.3582
# INFO:root:After epoch 742, Sparsity = 90.0
# After epoch 742, Reconstruction Loss = 0.1537, ASL = 0.0000,PSL = 0.2563, and total = 0.3587
# INFO:root:After epoch 743, Sparsity = 90.8
# After epoch 743, Reconstruction Loss = 0.1564, ASL = 0.0000,PSL = 0.2532, and total = 0.3590
# INFO:root:After epoch 744, Sparsity = 90.5
# After epoch 744, Reconstruction Loss = 0.1559, ASL = 0.0000,PSL = 0.2538, and total = 0.3589
# INFO:root:After epoch 745, Sparsity = 90.8
# After epoch 745, Reconstruction Loss = 0.1554, ASL = 0.0000,PSL = 0.2536, and total = 0.3583
# INFO:root:After epoch 746, Sparsity = 91.0
# After epoch 746, Reconstruction Loss = 0.1542, ASL = 0.0000,PSL = 0.2506, and total = 0.3547
# INFO:root:After epoch 747, Sparsity = 90.7
# After epoch 747, Reconstruction Loss = 0.1542, ASL = 0.0000,PSL = 0.2515, and total = 0.3554
# INFO:root:After epoch 748, Sparsity = 90.4
# After epoch 748, Reconstruction Loss = 0.1569, ASL = 0.0000,PSL = 0.2517, and total = 0.3583
# INFO:root:After epoch 749, Sparsity = 91.3
# After epoch 749, Reconstruction Loss = 0.1544, ASL = 0.0000,PSL = 0.2489, and total = 0.3535
# INFO:root:After epoch 750, Sparsity = 91.3
# After epoch 750, Reconstruction Loss = 0.1578, ASL = 0.0000,PSL = 0.2485, and total = 0.3566
# INFO:root:After epoch 751, Sparsity = 90.9
# After epoch 751, Reconstruction Loss = 0.1544, ASL = 0.0000,PSL = 0.2490, and total = 0.3537
# INFO:root:After epoch 752, Sparsity = 91.2
# After epoch 752, Reconstruction Loss = 0.1546, ASL = 0.0000,PSL = 0.2468, and total = 0.3521
# INFO:root:After epoch 753, Sparsity = 91.2
# After epoch 753, Reconstruction Loss = 0.1569, ASL = 0.0000,PSL = 0.2445, and total = 0.3525
# INFO:root:After epoch 754, Sparsity = 91.3
# After epoch 754, Reconstruction Loss = 0.1550, ASL = 0.0000,PSL = 0.2464, and total = 0.3521
# INFO:root:After epoch 755, Sparsity = 90.8
# After epoch 755, Reconstruction Loss = 0.1542, ASL = 0.0000,PSL = 0.2456, and total = 0.3507
# INFO:root:After epoch 756, Sparsity = 91.1
# After epoch 756, Reconstruction Loss = 0.1544, ASL = 0.0000,PSL = 0.2456, and total = 0.3509
# INFO:root:After epoch 757, Sparsity = 91.2
# After epoch 757, Reconstruction Loss = 0.1540, ASL = 0.0000,PSL = 0.2431, and total = 0.3485
# INFO:root:After epoch 758, Sparsity = 91.2
# After epoch 758, Reconstruction Loss = 0.1534, ASL = 0.0000,PSL = 0.2435, and total = 0.3482
# INFO:root:After epoch 759, Sparsity = 91.3
# After epoch 759, Reconstruction Loss = 0.1542, ASL = 0.0000,PSL = 0.2414, and total = 0.3474
# INFO:root:After epoch 760, Sparsity = 91.1
# After epoch 760, Reconstruction Loss = 0.1536, ASL = 0.0000,PSL = 0.2413, and total = 0.3467
# INFO:root:After epoch 761, Sparsity = 90.9
# After epoch 761, Reconstruction Loss = 0.1552, ASL = 0.0000,PSL = 0.2417, and total = 0.3485
# INFO:root:After epoch 762, Sparsity = 91.0
# After epoch 762, Reconstruction Loss = 0.1545, ASL = 0.0000,PSL = 0.2396, and total = 0.3462
# INFO:root:After epoch 763, Sparsity = 91.5
# After epoch 763, Reconstruction Loss = 0.1547, ASL = 0.0000,PSL = 0.2377, and total = 0.3448
# INFO:root:After epoch 764, Sparsity = 90.9
# After epoch 764, Reconstruction Loss = 0.1542, ASL = 0.0000,PSL = 0.2381, and total = 0.3446
# INFO:root:After epoch 765, Sparsity = 91.3
# After epoch 765, Reconstruction Loss = 0.1543, ASL = 0.0000,PSL = 0.2376, and total = 0.3444
# INFO:root:After epoch 766, Sparsity = 91.4
# After epoch 766, Reconstruction Loss = 0.1556, ASL = 0.0000,PSL = 0.2348, and total = 0.3434
# INFO:root:After epoch 767, Sparsity = 91.1
# After epoch 767, Reconstruction Loss = 0.1541, ASL = 0.0000,PSL = 0.2358, and total = 0.3427
# INFO:root:After epoch 768, Sparsity = 90.9
# After epoch 768, Reconstruction Loss = 0.1534, ASL = 0.0000,PSL = 0.2364, and total = 0.3425
# INFO:root:After epoch 769, Sparsity = 91.6
# After epoch 769, Reconstruction Loss = 0.1543, ASL = 0.0000,PSL = 0.2340, and total = 0.3415
# INFO:root:After epoch 770, Sparsity = 91.4
# After epoch 770, Reconstruction Loss = 0.1531, ASL = 0.0000,PSL = 0.2350, and total = 0.3412
# INFO:root:After epoch 771, Sparsity = 90.9
# After epoch 771, Reconstruction Loss = 0.1533, ASL = 0.0000,PSL = 0.2344, and total = 0.3409
# INFO:root:After epoch 772, Sparsity = 91.2
# After epoch 772, Reconstruction Loss = 0.1528, ASL = 0.0000,PSL = 0.2330, and total = 0.3392
# INFO:root:After epoch 773, Sparsity = 91.3
# After epoch 773, Reconstruction Loss = 0.1545, ASL = 0.0000,PSL = 0.2304, and total = 0.3389
# INFO:root:After epoch 774, Sparsity = 91.3
# After epoch 774, Reconstruction Loss = 0.1529, ASL = 0.0000,PSL = 0.2300, and total = 0.3368
# INFO:root:After epoch 775, Sparsity = 91.5
# After epoch 775, Reconstruction Loss = 0.1543, ASL = 0.0000,PSL = 0.2295, and total = 0.3379
# INFO:root:After epoch 776, Sparsity = 91.7
# After epoch 776, Reconstruction Loss = 0.1539, ASL = 0.0000,PSL = 0.2282, and total = 0.3364
# INFO:root:After epoch 777, Sparsity = 91.4
# After epoch 777, Reconstruction Loss = 0.1559, ASL = 0.0000,PSL = 0.2287, and total = 0.3388
# INFO:root:After epoch 778, Sparsity = 91.4
# After epoch 778, Reconstruction Loss = 0.1537, ASL = 0.0000,PSL = 0.2281, and total = 0.3362
# INFO:root:After epoch 779, Sparsity = 91.3
# After epoch 779, Reconstruction Loss = 0.1534, ASL = 0.0000,PSL = 0.2261, and total = 0.3343
# INFO:root:After epoch 780, Sparsity = 91.5
# After epoch 780, Reconstruction Loss = 0.1531, ASL = 0.0000,PSL = 0.2260, and total = 0.3339
# INFO:root:After epoch 781, Sparsity = 91.4
# After epoch 781, Reconstruction Loss = 0.1535, ASL = 0.0000,PSL = 0.2261, and total = 0.3344
# INFO:root:After epoch 782, Sparsity = 91.5
# After epoch 782, Reconstruction Loss = 0.1538, ASL = 0.0000,PSL = 0.2249, and total = 0.3337
# INFO:root:After epoch 783, Sparsity = 91.6
# After epoch 783, Reconstruction Loss = 0.1539, ASL = 0.0000,PSL = 0.2237, and total = 0.3328
# INFO:root:After epoch 784, Sparsity = 91.6
# After epoch 784, Reconstruction Loss = 0.1526, ASL = 0.0000,PSL = 0.2229, and total = 0.3309
# INFO:root:After epoch 785, Sparsity = 91.6
# After epoch 785, Reconstruction Loss = 0.1549, ASL = 0.0000,PSL = 0.2232, and total = 0.3335
# INFO:root:After epoch 786, Sparsity = 91.5
# After epoch 786, Reconstruction Loss = 0.1548, ASL = 0.0000,PSL = 0.2219, and total = 0.3323
# INFO:root:After epoch 787, Sparsity = 91.6
# After epoch 787, Reconstruction Loss = 0.1533, ASL = 0.0000,PSL = 0.2205, and total = 0.3297
# INFO:root:After epoch 788, Sparsity = 91.4
# After epoch 788, Reconstruction Loss = 0.1530, ASL = 0.0000,PSL = 0.2206, and total = 0.3295
# INFO:root:After epoch 789, Sparsity = 91.2
# After epoch 789, Reconstruction Loss = 0.1530, ASL = 0.0000,PSL = 0.2207, and total = 0.3296
# INFO:root:After epoch 790, Sparsity = 91.7
# After epoch 790, Reconstruction Loss = 0.1534, ASL = 0.0000,PSL = 0.2204, and total = 0.3297
# INFO:root:After epoch 791, Sparsity = 91.1
# After epoch 791, Reconstruction Loss = 0.1544, ASL = 0.0000,PSL = 0.2214, and total = 0.3316
# INFO:root:After epoch 792, Sparsity = 91.9
# After epoch 792, Reconstruction Loss = 0.1529, ASL = 0.0000,PSL = 0.2193, and total = 0.3284
# INFO:root:After epoch 793, Sparsity = 91.4
# After epoch 793, Reconstruction Loss = 0.1521, ASL = 0.0000,PSL = 0.2193, and total = 0.3276
# INFO:root:After epoch 794, Sparsity = 92.0
# After epoch 794, Reconstruction Loss = 0.1530, ASL = 0.0000,PSL = 0.2175, and total = 0.3270
# INFO:root:After epoch 795, Sparsity = 91.6
# After epoch 795, Reconstruction Loss = 0.1532, ASL = 0.0000,PSL = 0.2168, and total = 0.3266
# INFO:root:After epoch 796, Sparsity = 91.7
# After epoch 796, Reconstruction Loss = 0.1541, ASL = 0.0000,PSL = 0.2150, and total = 0.3261
# INFO:root:After epoch 797, Sparsity = 91.7
# After epoch 797, Reconstruction Loss = 0.1524, ASL = 0.0000,PSL = 0.2156, and total = 0.3249
# INFO:root:After epoch 798, Sparsity = 91.8
# After epoch 798, Reconstruction Loss = 0.1516, ASL = 0.0000,PSL = 0.2135, and total = 0.3224
# INFO:root:After epoch 799, Sparsity = 91.6
# After epoch 799, Reconstruction Loss = 0.1520, ASL = 0.0000,PSL = 0.2125, and total = 0.3220
# INFO:root:After epoch 800, Sparsity = 92.4
# INFO:root:Dumping the final SPine embeddings
# DEBUG:root:original_data[0][0:5] = [-0.04570577 -0.07722437 -0.0188346   0.05359886  0.140308  ]
# After epoch 800, Reconstruction Loss = 0.1546, ASL = 0.0000,PSL = 0.2136, and total = 0.3255
# shape (14942, 1000)

# %%
# !cp fastext_embedding.txt_SPINE.spine /content/gdrive/MyDrive/fastext_embedding.txt_SPINE.spine

# %% [markdown]
# # Evaluating results

# %%
from multiprocessing import Queue
from queue import PriorityQueue
from numpy import linalg as LA
from scipy import stats
import numpy as np
import argparse
import time
import sys
import os
from tqdm import tqdm

class Visualize:
  def __init__(self,filename):
    self.top_k_words = []
    self.zeros=0.0
    self.threshold = 0.001
    self.total = None
    self.width = 5
    self.vectors = None
    self.fileName = filename
    self.load_vectors()
  def data_read(self,line):
    
    tokens = line.strip().split("<pad2a>")
    tokens_sent=tokens[1]
    tokens_val=tokens[2]
    # tokens_sent=tokens_sent.split()
    tokens_val=tokens_val.split()
    return tokens_sent,tokens_val
  def load_vectors(self):
    
    self.vectors = {}
    self.zeros = 0.0
    f = open(self.fileName, 'r')
    lines = f.readlines()
    f.close()
    _,values=self.data_read(lines[0])
    dimension = len(values)
    self.top_k_words = [ [] for i in range(dimension)]
    c = 0
    for line in tqdm(lines):
        start = time.time()
        sentence,values=self.data_read(line)
        sentence=sentence.replace(" ","")
        self.vectors[sentence] = [abs(float(i)) for i in values]
        self.h_dim = len(values)
        c += 1
        vector = self.vectors[sentence]
        for i, val in enumerate(vector):
          temp = self.top_k_words[i]
          if len(temp) < self.width:
            temp.append((val,sentence))
          else:
            check = temp[-1]
            if check[0] < val:
              temp[-1] = (val, sentence)
          self.top_k_words[i] = sorted(temp, reverse=True)
        self.zeros += sum([1 for i in self.vectors[sentence] if i < self.threshold])
    print ("Sparsity =", 100. * self.zeros/(len(lines)*dimension))
    self.total = len(self.vectors)
    print ('done loading vectors')
  def load_top_dimensions(self,k):
    self.top_k_words
    return
    self.dimensions = len(self.vectors[self.vectors.keys()[0]])
    for i in range(self.dimensions):
      temp = []
      while self.top_k_words[i].qsize() > 0:
        temp.append(self.top_k_words.get_nowait()[1])
      self.top_k_words[i] = temp
    print ('loaded top dimensions')
  def find_top_participating_dimensions(self,word, k):
    if word not in self.vectors:
      print ('word not found')
      return []
    temp = [(j, i) for i, j in enumerate(self.vectors[word])]
    answer = []
    print (" -----------------------------------------------------")
    print ("Word of interest = " , word)
    for i, j in sorted(temp, reverse=True)[:k]:
      print ("The contribution of the word '%s' in dimension %d = %f" %(word, j, i))
      print ('Following are the top words in dimension', j, 'along with their contributions')
      print (self.top_k_words[j])
      answer.append([k[1] for k in self.top_k_words[j]])
    return

# %% [markdown]
# # Before Training results

# %%
filename_input='/content/fastext_embedding.txt'
bt_fast2Text=Visualize(filename_input)
# Out:
# 100%|██████████| 14942/14942 [00:05<00:00, 2703.91it/s]
# Sparsity = 1.750301164502744
# done loading vectors

# %%
print('###############################################')
print('#################Before training###############')
print('###############################################')
bt_fast2Text.find_top_participating_dimensions("mathematics",3)
# Out:
# ###############################################
# #################Before training###############
# ###############################################
#  -----------------------------------------------------
# Word of interest =  mathematics
# The contribution of the word 'mathematics' in dimension 170 = 0.084210
# Following are the top words in dimension 170 along with their contributions
# [(0.7667661, 'db'), (0.7625639, 'sq'), (0.71935683, 'cw'), (0.7136442, 'mhz'), (0.62827873, 'eu')]
# The contribution of the word 'mathematics' in dimension 29 = 0.084083
# Following are the top words in dimension 29 along with their contributions
# [(2.1108575, 'qi'), (2.0701993, 'gb'), (1.9410158, 'eu'), (1.8451892, 'ip'), (1.8094333, 'mg')]
# The contribution of the word 'mathematics' in dimension 247 = 0.082030
# Following are the top words in dimension 247 along with their contributions
# [(0.69344264, 'qi'), (0.68157285, 'yi'), (0.64657867, 'sc'), (0.5215695, 'hp'), (0.48675546, 'sac')]

# %% [markdown]
# # After Training results

# %%
fileAlreadyAvailble=True
if fileAlreadyAvailble==True:
  filename_trained='/content/gdrive/MyDrive/fastext_embedding.txt_SPINE.spine'
else:
  file_name_trained='fastext_embedding.txt_SPINE.spine'
at_fast2Text=Visualize(filename_trained)
# Out:
# /content/gdrive/MyDrive/fastext_embedding.txt_SPINE.spine
# 100%|██████████| 14942/14942 [00:20<00:00, 726.14it/s]
# Sparsity = 91.9444318029715
# done loading vectors

# %%
print('###############################################')
print('#################After sparsing###############')
print('###############################################')
at_fast2Text.find_top_participating_dimensions("mathematics",3)
# Out:
# ###############################################
# #################After sparsing###############
# ###############################################
#  -----------------------------------------------------
# Word of interest =  mathematics
# The contribution of the word 'mathematics' in dimension 791 = 0.426294
# Following are the top words in dimension 791 along with their contributions
# [(0.6023267, 'surfaces'), (0.5668529, 'one'), (0.54609597, 'arrive'), (0.5217295, 'chaired'), (0.5123727, 'memorable')]
# The contribution of the word 'mathematics' in dimension 153 = 0.280674
# Following are the top words in dimension 153 along with their contributions
# [(0.5753157, 'aston'), (0.5191753, 'slang'), (0.50999105, 'flower'), (0.49187788, 'troupe'), (0.47234085, 'symposium')]
# The contribution of the word 'mathematics' in dimension 359 = 0.244773
# Following are the top words in dimension 359 along with their contributions
# [(0.6244252, 'notation'), (0.57416034, 'soldiers'), (0.5450934, 'persia'), (0.53640866, 'veterinary'), (0.48237428, 'instructor')]
